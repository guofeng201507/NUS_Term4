# %% [markdown]
# # Advanced Text Analysis with SpaCy and Scikit-Learn
#
# This notebook was originally prepared for the workshop [Advanced Text Analysis with SpaCy and Scikit-Learn](http://dhweek.nycdh.org/event/advanced-text-analysis-with-spacy-and-scikit-learn/), presented as part of NYCDH Week 2017. Here, we try out features of the SpaCy library for natural language processing. We also do some statistical analysis using from the scikit-learn library.
#
# Modifed from [Jonathan Reeve](http://jonreeve.com) ([Group for Experimental Methods in the Humanities](http://xpmethod.plaintext.in/), Columbia University).

# %%
# !pip install sent2vec
# Out:
# Collecting sent2vec
#   Could not find a version that satisfies the requirement sent2vec (from versions: )
# No matching distribution found for sent2vec

# %%
import spacy
import pandas as pd
import numpy as np
from collections import Counter
from glob import glob
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer

# Display plots in this notebook, instead of externally. 
from pylab import rcParams
rcParams['figure.figsize'] = 16, 8
# %matplotlib inline

# The following are optional dependencies. 
# Feel free to comment these out. Otherwise you need to pip install them
# Sent2tree uses the sent2tree.py module in this repository. 
from sent2tree import sentenceTree
import ete3 # data visualisation library
import seaborn # data visualisation library
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-f54cd7c6e14a> in <module>
#      17 # Feel free to comment these out. Otherwise you need to pip install them
#      18 # Sent2tree uses the sent2tree.py module in this repository.
# ---> 19 from sent2tree import sentenceTree
#      20 import ete3 # data visualisation library
#      21 import seaborn # data visualisation library
#
# ~\workspace\NUS_Term4\NMSM\WK1-2\sent2tree.py in <module>
#       1 import ete3
# ----> 2 from ete3 import Tree, TreeStyle, TextFace, add_face_to_node
#       3
#       4 class sentenceTree():
#       5     def __init__(self, sent):
#
# ImportError: cannot import name 'TreeStyle'

# %%
# This command might take a little while -> sm/ md
# There are some default library models that are built by spacy. These are either sm (small model with limited features), 
# md (mid model) and lg (large model takes longer to load).
# https://spacy.io/usage/models # you may need to run this
#!python -m spacy download en_core_web_sm  
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# The sample data is the script of the 1975 film _Monty Python and the Holy Grail_, taken from the NLTK Book corpus, and the Project Gutenberg edition of Jane Austen's novel _Pride and Prejudice_.

# %%
grail_raw = open('data/grail.txt',mode='r',encoding='utf-8')
pride_raw = open('data/pride.txt',mode='r',encoding='utf-8')

# %%
# Parse the texts. These commands might take a little while. 
grail = nlp(grail_raw.read())
pride = nlp(pride_raw.read())

# %% [markdown]
# # Exploring the Document
#
# Each SpaCy document is already tokenized into words, which are accessible by iterating over the document:

# %%
#print (pride[0])
print (pride[1:10])
# Out:
# is a truth universally acknowledged, that a single

# %% [markdown]
# You can break up into sentences and iterate over it. `doc.sents` is a generator object, so we can use `next()`:

# %%
next(pride.sents)
# Out:
# ﻿It is a truth universally acknowledged, that a single man in possession
# of a good fortune, must be in want of a wife.

# %% [markdown]
# Or you can force it into a list, and then do things with it:

# %%
prideSents = list(pride.sents)
prideSents[-1] # last sentence
# Out:
# Darcy, as well as Elizabeth, really loved them; and they were both ever
# sensible of the warmest gratitude towards the persons who, by bringing
# her into Derbyshire, had been the means of uniting them.

# %%
list(grail.sents)[-1]
# Out:
# CAMERAMAN: Christ!

# %% [markdown]
# For example, let's find the longest sentence(s) in _Pride and Prejudice_:

# %%
prideSentenceLengths = [len(sent) for sent in prideSents]
[sent for sent in prideSents if len(sent) == max(prideSentenceLengths)]
# Out:
# [“I am by no means of the opinion, I assure you,” said he, “that a ball
#  of this kind, given by a young man of character, to respectable people,
#  can have any evil tendency; and I am so far from objecting to dancing
#  myself, that I shall hope to be honoured with the hands of all my fair
#  cousins in the course of the evening; and I take this opportunity of
#  soliciting yours, Miss Elizabeth, for the two first dances especially,
#  a preference which I trust my cousin Jane will attribute to the right
#  cause, and not to any disrespect for her.”
#  , The idea of Mr. Collins, with all his solemn composure, being run away
#  with by his feelings, made Elizabeth so near laughing, that she could
#  not use the short pause he allowed in any attempt to stop him further,
#  and he continued:
#
#  “My reasons for marrying are, first, that I think it a right thing for
#  every clergyman in easy circumstances (like myself) to set the example
#  of matrimony in his parish; secondly, that I am convinced that it will
#  add very greatly to my happiness; and thirdly--which perhaps I ought
#  to have mentioned earlier, that it is the particular advice and]

# %% [markdown]
# ## Exploring Words
#
# Each token has a crazy number of properties:

# %%
# .i shows the where the word is located
def locations(needle, haystack): 
    """ 
    Make a list of locations, bin those into a histogram, 
    and  put it into a Pandas Series object for analysis
    """
    return pd.Series(np.histogram(
        [word.i for word in haystack 
         if word.text.lower() == needle], bins=50)[0])

# %%
rcParams['figure.figsize'] = 16, 8

pd.DataFrame(
    {name: locations(name.lower(), pride) 
     for name in ['Elizabeth', 'Darcy', 'Jane', 'Bennet']}  # look for where the character names are
).plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001364C27A548>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000013600149D48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000136001838C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000136001BB4C8>],
#       dtype=object)

# %% [markdown]
# Looking at the plots, we can then tell which characters tend to appear together in the script.

# %% [markdown]
# # Exploring Named Entities
#
# Named entities can be accessed through `doc.ents`. Let's find all the types of named entities from _Monty Python and the Holy Grail_:

# %%
set([w.label_ for w in grail.ents])
# these show the type of entities
# Out:
# {'CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART'}

# %% [markdown]
# What about those that are works of art?

# %%
[ent for ent in grail.ents if ent.label_ == 'PERSON']
# then, it refers back to the original words. Note spacy is smart enough to do n-grams
# Out:
# [Arthur,
#  Patsy,
#  Ridden,
#  Arthur,
#  Robinson,
#  Arthur,
#  Arthur,
#  Sorry,
#  Dennis,
#  Dennis,
#  Dennis,
#  Arthur,
#  Divine Providence,
#  Arthur,
#  Arthur,
#  Aaagh,
#  Arthur,
#  Ooh,
#  Arthur,
#  Aagh,
#  Arthur,
#  Ooh,
#  Aaagh,
#  Agh,
#  Knight,
#  Arthur,
#  Patsy,
#  Knight,
#  Hiyaah,
#  Thee Lord,
#  Knight,
#  The Black Knight,
#  Patsy,
#  MONKS,
#  dona eis requiem,
#  bonk,
#  bonk,
#  dona eis requiem,
#  bonk,
#  bonk,
#  dona eis requiem,
#  bonk,
#  MONKS,
#  Burn,
#  Burn,
#  Burn,
#  WITCH,
#  Yeaah,
#  Ohh,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Burn,
#  Arthur,
#  Knight,
#  Knight,
#  NARRATOR,
#  Bedevere,
#  Gallahad the Pure,
#  Robin,
#  Bristol,
#  Shh,
#  Knights,
#  Clark Gable,
#  KNIGHTS,
#  Arthur,
#  Arthur,
#  Arthur,
#  Behold,
#  Arthur,
#  Arthur,
#  Arthur,
#  Arthur,
#  King Arthur,
#  Guy de Loimbard,
#  Jesus Christ,
#  KNIGHTS,
#  KNIGHTS,
#  Run,
#  KNIGHTS,
#  Run,
#  FRENCH,
#  FRENCH,
#  lapin de bois,
#  Quoi,
#  Bon,
#  Run,
#  KNIGHTS,
#  Run,
#  Run,
#  Run,
#  Run,
#  Run,
#  Run,
#  Run,
#  FRENCH,
#  DIRECTOR,
#  Arthur,
#  Arthur,
#  KNIGHT,
#  Frank,
#  Robin,
#  Robin,
#  MINSTREL,
#  Robin,
#  Robin,
#  Brave,
#  Robin,
#  Robin,
#  ROBIN,
#  Dennis,
#  MINSTREL,
#  Robin,
#  Robin,
#  MINSTREL,
#  Knight,
#  MINSTREL,
#  Robin,
#  ROBIN,
#  MINSTREL,
#  ROBIN,
#  MINSTREL,
#  ROBIN,
#  MINSTREL,
#  Robin,
#  MINSTREL,
#  MINSTREL,
#  MINSTREL,
#  Robin,
#  dona eis requiem,
#  Ho ho,
#  Woa,
#  dona eis requiem,
#  King Arthur,
#  Knight,
#  ZOOT,
#  ZOOT,
#  ZOOT,
#  Crapper,
#  MIDGET,
#  CRAPPER,
#  Zoot,
#  ZOOT,
#  MIDGET,
#  CRAPPER,
#  ZOOT,
#  Galahad,
#  Zoot,
#  Zoot,
#  ZOOT,
#  Galahad,
#  Nay,
#  ZOOT,
#  Lie,
#  ZOOT,
#  but--,
#  ZOOT,
#  Piglet,
#  Winston,
#  WINSTON,
#  Zoot,
#  Zoot,
#  Dingo,
#  Grail,
#  Zoot,
#  Zoot,
#  Zoot,
#  TIM,
#  Zoot,
#  AMAZING,
#  Galahad,
#  Galahad,
#  Galahad,
#  Launcelot,
#  Galahad,
#  Arthur,
#  Heh,
#  Peng,
#  Neee,
#  Neee-wom,
#  Knights of Ni,
#  KNIGHTS,
#  Agh,
#  KNIGHTS,
#  ARTHUR,
#  Ayy,
#  Ayy,
#  Mother--,
#  Herbert,
#  Erbert,
#  if-- if-- if-- uhh--,
#  if-- if--,
#  if--,
#  if--,
#  Concorde,
#  Brave,
#  Hiyya,
#  Hiyya,
#  GUESTS,
#  Aah,
#  Hiyah,
#  Aah,
#  Hiyya,
#  HERBERT,
#  Launcelot,
#  Launcelot,
#  HERBERT,
#  thonk,
#  GUESTS,
#  Launcelot,
#  GUESTS,
#  Herbert,
#  GUESTS,
#  Launcelot,
#  GUESTS,
#  HERBERT,
#  HERBERT,
#  GUESTS,
#  GUESTS,
#  Hoa,
#  GUESTS,
#  Arthur,
#  Agh,
#  ARTHUR,
#  ARTHUR,
#  ROGER,
#  Roger,
#  Shh,
#  Shh,
#  KNIGHTS,
#  Shh,
#  Shh,
#  Shh,
#  KNIGHTS,
#  KNIGHTS,
#  KNIGHTS,
#  Robin,
#  MINSTREL,
#  Robin,
#  ROBIN,
#  MINSTREL,
#  KNIGHTS,
#  ROBIN,
#  KNIGHTS,
#  ROBIN,
#  KNIGHTS,
#  Patsy,
#  Ohh,
#  Arthur,
#  Robin,
#  KNIGHTS,
#  Yay,
#  Yay,
#  Robin,
#  MINSTREL,
#  KNIGHTS,
#  Yay,
#  NARRATOR,
#  Mmm,
#  Arthur,
#  Knights,
#  TIM,
#  TIM,
#  Tim,
#  Tim,
#  TIM,
#  Arthur,
#  TIM,
#  Tim,
#  TIM,
#  KNIGHTS,
#  ROBIN,
#  TIM,
#  TIM,
#  TIM,
#  ROBIN,
#  ROBIN,
#  KNIGHTS,
#  TIM,
#  KNIGHTS,
#  TIM,
#  Tim,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  TIM,
#  ROBIN,
#  TIM,
#  TIM,
#  ROBIN,
#  TIM,
#  ROBIN,
#  TIM,
#  TIM,
#  Jesus Christ,
#  TIM,
#  ROBIN,
#  TIM,
#  TIM,
#  TIM,
#  KNIGHTS,
#  Run,
#  Run,
#  KNIGHTS,
#  Run,
#  Run,
#  TIM,
#  Maynard,
#  Maynard,
#  MONKS,
#  dona eis requiem,
#  dona eis requiem,
#  Saint Attila,
#  grin,
#  lobbest thou,
#  Maynard,
#  Joseph,
#  Arimathea,
#  Joseph of Arimathea,
#  Oooooooh,
#  Run,
#  KNIGHTS,
#  Run,
#  Run,
#  Run,
#  Run,
#  Shh,
#  Shh,
#  Shh,
#  Shh,
#  Shh,
#  Shh,
#  Shh,
#  Shh,
#  Aagh,
#  Arthur,
#  ROBIN,
#  Robin,
#  ROBIN,
#  Robin,
#  ROBIN,
#  Launcelot,
#  ROBIN,
#  Robin,
#  Galahad,
#  Arthur,
#  Thee,
#  Thou,
#  Jesus Christ,
#  Monsieur Arthur King,
#  FRENCH GUARDS,
#  FRENCH,
#  FRENCH GUARDS,
#  Dappy,
#  FRENCH,
#  Ohh,
#  FRENCH,
#  Run,
#  Run]

# %% [markdown]
# Place names?

# %%
[ent for ent in grail.ents if ent.label_ == 'GPE']
# Out:
# [England,
#  the kingdom of Mercea,
#  Huyah,
#  Chickennn,
#  the Dragon of Angnor,
#  England,
#  Galahad,
#  Galahad,
#  Haw,
#  Haw,
#  ju--,
#  Nay,
#  us,
#  us,
#  Bloody,
#  This'll,
#  Britain,
#  he--,
#  Galahad,
#  Nador,
#  Winter,
#  um--,
#  Holy Grail,
#  thine,
#  thou,
#  France,
#  Cornwall,
#  Oooohoohohooo]

# %% [markdown]
# Organizations?

# %%
set(list([ent.string.strip() for ent in grail.ents if ent.label_ == 'ORG']))
# Out:
# {'ARMY',
#  'Arthur',
#  'BEDEVERE',
#  'BRIDE',
#  'Bedevere',
#  'Britons',
#  'Castle Anthrax',
#  'Ewing',
#  'Excalibur',
#  'GUARD',
#  'GUESTS',
#  'Grail',
#  'HERBERT',
#  'HISTORIAN',
#  'Hm',
#  'Hurry',
#  'Huy',
#  'INSPECTOR',
#  'KNIGHTS',
#  'KNIGHTS OF NI',
#  'King Arthur',
#  "King Arthur's",
#  'Launcelot',
#  'MAYNARD',
#  'NARRATOR',
#  'Ohh',
#  'Olfin Bedwere of Rheged',
#  'Oooo',
#  'PATSY',
#  'Pie Iesu',
#  'ROBIN',
#  'Shrubberies',
#  'Supreme',
#  'Tell',
#  'The Holy Hand Grenade of Antioch',
#  'The Tale of Sir Launcelot',
#  'Thsss',
#  'Un',
#  'Uther Pendragon',
#  'Uuh',
#  'VILLAGER',
#  'VILLAGERS',
#  'Yeaaah',
#  'mac',
#  'mooo',
#  "the BLACK KNIGHT's",
#  "the Castle of uuggggggh'",
#  'the Court of Camelot',
#  'the Gorge of Eternal Peril',
#  'the Holy Grail',
#  'the Holy Hand Grenade',
#  'the Knights of Camelot',
#  'the Knights of the Round Table',
#  'un cadeau'}

# %% [markdown]
# How about groups of people?

# %%
set([ent.string for ent in grail.ents if ent.label_ == 'NORP'])
# Out:
# {'African ',
#  'Assyria',
#  'European ',
#  'French',
#  'French ',
#  'I. ',
#  'Thpppt',
#  'orangutans '}

# %% [markdown]
# "French" here refers to French _people_, not the French language. We can verify that by getting all the sentences in which this particular type of entity occurs:

# %%
frenchPeople = [ent for ent in grail.ents if ent.label_ == 'NORP' and ent.string.strip() == 'French']
[ent.sent for ent in frenchPeople]
# Out:
# [Well, now, uh, Launcelot, Galahad, and I, uh, wait until nightfall, and then leap out of the rabbit, taking the French, uh, by surprise.  ,
#  The ferocity of the French taunting took him completely by surprise, and Arthur became convinced that a new strategy was required if the quest for the Holy Grail were to be brought to a successful conclusion.  ,
#  So, we French fellows,
#  So, you think you could out-clever us French folk with your silly knees-bent running about advancing behaviour?!  ,
#  French persons!]

# %% [markdown]
# Let's try on the level of a sentence. First, let's get all the sentences in which Sir Robin is explicitly mentioned:

# %%
robinSents = [sent for sent in grail.sents if 'Sir Robin' in sent.string]
robinSents
# Out:
# [The wise Sir Bedevere was the first to join King Arthur's knights, but other illustrious names were soon to follow: Sir Lancelot the Brave; Sir Gallahad the Pure; and Sir Robin,
#  The Tale of Sir Robin.  ,
#  Sir Robin rode north, through the dark forest of Ewing, accompanied by his favorite minstrels.,
#  [singing] Bravely bold Sir Robin, rode forth from Camelot.  ,
#  He was not afraid to die, O brave Sir Robin.  ,
#  Brave, brave, brave, brave Sir Robin!  ,
#  To have his kneecaps split, and his body burned away, And his limbs all hacked and mangled, brave Sir Robin!,
#  He is brave Sir Robin, brave Sir Robin,,
#  Brave Sir Robin ran away.,
#  Yes, brave Sir Robin turned about,
#  [singing] Bravest of the brave, Sir Robin.
#  ROBIN: I never
#  CARTOON MONKS: [chanting] Pie Iesu domine, dona eis requiem.,
#  My liege, it's Sir Robin!
#  MINSTREL: [singing] Packing it in and packing it up, And sneaking away and buggering up, And chickening out and pissing off home, Yes, bravely he is throwing in the sponge.,
#  Sir Robin!,
#  And so, Arthur and Bedevere and Sir Robin set out on their search to find the enchanter of whom the old man had spoken in scene twenty-four.  ,
#  Sir Robin!,
#  Brave Sir Robin, you go.,
#  Sir Robin of Camelot.]

# %% [markdown]
# ### Analysing one of the sentences

# %%
r2 = robinSents[2]
r2
# Out:
# Sir Robin rode north, through the dark forest of Ewing, accompanied by his favorite minstrels.

# %% [markdown]
# Let's look at the tags and parts of speech:

# %%
for word in r2: 
    print(word, word.tag_, word.pos_)
# Out:
# Sir NNP PROPN
# Robin NNP PROPN
# rode VBD VERB
# north RB ADV
# , , PUNCT
# through IN ADP
# the DT DET
# dark JJ ADJ
# forest NN NOUN
# of IN ADP
# Ewing NNP PROPN
# , , PUNCT
# accompanied VBN VERB
# by IN ADP
# his PRP$ DET
# favorite JJ ADJ
# minstrels NNS NOUN
# . . PUNCT
#
#  _SP SPACE

# %% [markdown]
# Perform an analysis to determine who are the characters that are 'talking', 'saying', 'doing' the most. Find the relationship between entities and corresponding root verbs

# %%
character_verb_counter = Counter()
VERB_LEMMA = 'do'  # say

for ent in pride.ents:
    if ent.label_ == 'PERSON' and ent.root.head.lemma_ == VERB_LEMMA:
        character_verb_counter[ent.text] += 1

print(character_verb_counter.most_common(10)) 
        
# Find all the characters that got married in the book.
#
# Here is an example sentence from which this information could be extracted:
# 
# "her mother was talking to that one person (Lady Lucas) freely,
# openly, and of nothing else but her expectation that Jane would soon
# be married to Mr. Bingley."
#
# Out:
# [('Darcy', 5), ('Bingley', 4), ('Lizzy', 4), ('Elizabeth', 3), ('Gardiner', 3), ('Long', 1), ('William', 1), ('Louisa', 1), ('Lucas', 1), ('Lady Catherine', 1)]

# %% [markdown]
# ### Available properties in sentence tokens
#
# Let's observe the properties in the sentence r2.

# %%
[prop for prop in dir(r2) if not prop.startswith('_')]
# Out:
# ['as_doc',
#  'conjuncts',
#  'doc',
#  'end',
#  'end_char',
#  'ent_id',
#  'ent_id_',
#  'ents',
#  'get_extension',
#  'get_lca_matrix',
#  'has_extension',
#  'has_vector',
#  'kb_id',
#  'kb_id_',
#  'label',
#  'label_',
#  'lefts',
#  'lemma_',
#  'lower_',
#  'merge',
#  'n_lefts',
#  'n_rights',
#  'noun_chunks',
#  'orth_',
#  'remove_extension',
#  'rights',
#  'root',
#  'sent',
#  'sentiment',
#  'set_extension',
#  'similarity',
#  'start',
#  'start_char',
#  'string',
#  'subtree',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'to_array',
#  'upper_',
#  'vector',
#  'vector_norm',
#  'vocab']

# %% [markdown]
# To drill down into the sentence, we can start with the root of the sentence - from which all the tokens emanate.

# %%
r2.root
# Out:
# rode

# %% [markdown]
# That root has children:

# %%
list(r2.root.children)
# Out:
# [Robin, north, ,, through, ,, accompanied, .]

# %% [markdown]
# Let's see all of the children for each word:

# %%
for word in r2: 
    print(word, ': ', str(list(word.children)))
# Out:
# Sir :  []
# Robin :  [Sir]
# rode :  [Robin, north, ,, through, ,, accompanied, .]
# north :  []
# , :  []
# through :  [forest]
# the :  []
# dark :  []
# forest :  [the, dark, of]
# of :  [Ewing]
# Ewing :  []
# , :  []
# accompanied :  [by]
# by :  [minstrels]
# his :  []
# favorite :  []
# minstrels :  [his, favorite]
# . :  [
# ]
#
#  :  []

# %% [markdown]
# This is very messy-looking, so let's create a nicer visualization. Here I'll be using a class I wrote called sentenceTree, available in the `sent2tree` module in this repository. It just shoehorns a SpaCy span (sentence or other grammatical fragment) into a tree that can be read by the `ete3` library for handling trees. This library just allows for some pretty visualizations of trees.

# %%
st = sentenceTree(r2)
t, ts = st.render()
t.render('%%inline', tree_style=ts)
# Out:
# Sir Robin rode north, through the dark forest of Ewing, accompanied by his favorite minstrels.

# %% [markdown]
# You can already see how useful this might be. Since adjectives are typically children of the things they describe, we can get approximations for adjectives that describe characters. How is Sir Robin described iterating through the child words that are adjective.

# %%
for sent in robinSents: 
    for word in sent: 
        if 'Robin' in word.string: 
            for child in word.children: 
                if child.pos_ == 'ADJ':
                    print(child)
# Out:
# bold
# brave
# brave
# brave
# brave
# brave

# %% [markdown]
# We need to do it on more sentences in the whole document. Now let's do something similar for Pride and Prejudice. First, we'll use named entity extraction to get a list of the most frequently mentioned characters:

# %%
Counter([w.string.strip() for w in pride.ents if w.label_ == 'PERSON']).most_common(10) 
# Counter is from the Collections library
# Out:
# [('Elizabeth', 623),
#  ('Darcy', 399),
#  ('Jane', 289),
#  ('Bennet', 270),
#  ('Bingley', 266),
#  ('Collins', 179),
#  ('Wickham', 114),
#  ('Lizzy', 93),
#  ('Gardiner', 91),
#  ('Lady Catherine', 87)]

# %% [markdown]
# Now we can write a function that walks down the tree from each character, looking for the first adjectives it can find:

# %%
def adjectivesDescribingCharacters(text, character):
    sents = [sent for sent in text.sents if character in sent.string]
    adjectives = []
    for sent in sents: 
        for word in sent: 
            if character in word.string:
                for child in word.children: 
                    if child.pos_ == 'ADJ': 
                        adjectives.append(child.string.strip())
    return Counter(adjectives).most_common(10)

# %% [markdown]
# We'll try it on Mr. Darcy:

# %%
adjectivesDescribingCharacters(pride, 'Darcy')
# Out:
# [('late', 6),
#  ('present', 2),
#  ('delighted', 1),
#  ('superior', 1),
#  ('abominable', 1),
#  ('poor', 1),
#  ('little', 1),
#  ('disagreeable', 1)]

# %% [markdown]
# Now let's do the same sort of thing, but look for associated verbs. First, let's get all the sentences in which Elizabeth is mentioned:

# %%
elizabethSentences = [sent for sent in pride.sents if 'Elizabeth' in sent.string]

# %% [markdown]
# And we can peek at one of them:

# %%
elizabethSentences[3]
# Out:
# Mr. Darcy walked off; and Elizabeth
# remained with no very cordial feelings toward him.

# %%
st = sentenceTree(elizabethSentences[3])
t, ts = st.render()
t.render('%%inline', tree_style=ts)
# Out:
# Mr. Darcy walked off; and Elizabeth
# remained with no very cordial feelings toward him.

# %% [markdown]
# We want the verb associated with Elizabeth, _remained_, not the root verb of the sentence, _walked_, which is associated with Mr. Darcy. So let's write a function that will walk up the dependency tree from a character's name until we get to the first verb. We'll use lemmas instead of the conjugated forms to collapse _remain_, _remains_, and _remained_ into one verb: _remain_.

# %%
def verbsForCharacters(text, character):
    sents = [sent for sent in pride.sents if character in sent.string]
    charWords = []
    for sent in sents: 
        for word in sent: 
            if character in word.string: 
                charWords.append(word)
    charAdjectives = []
    for word in charWords: 
        # Start walking up the list of ancestors 
        # Until we get to the first verb. 
        for ancestor in word.ancestors: 
            if ancestor.pos_.startswith('V'): 
                charAdjectives.append(ancestor.lemma_.strip())
    return Counter(charAdjectives).most_common(20)

# %%
elizabethVerbs = verbsForCharacters(pride, 'Elizabeth')
elizabethVerbs
# Out:
# [('say', 65),
#  ('cry', 24),
#  ('see', 23),
#  ('reply', 21),
#  ('feel', 19),
#  ('make', 18),
#  ('look', 15),
#  ('take', 11),
#  ('receive', 10),
#  ('think', 10),
#  ('listen', 9),
#  ('begin', 9),
#  ('walk', 8),
#  ('pass', 8),
#  ('help', 8),
#  ('find', 8),
#  ('go', 8),
#  ('turn', 7),
#  ('ask', 7),
#  ('smile', 7)]

# %%
darcyVerbs = verbsForCharacters(pride, 'Darcy')
janeVerbs = verbsForCharacters(pride, 'Jane')

# %% [markdown]
# We can now merge these counts into a single table, and then we can visualize it with Pandas.

# %%
def verbsToMatrix(verbCounts): 
    """ 
    Takes verb counts given by verbsForCharacters 
    and makes Pandas Series out of them, suitabe for combination in 
    a DataFrame. 
    """
    return pd.Series({t[0]: t[1] for t in verbCounts})

verbsDF = pd.DataFrame({'Elizabeth': verbsToMatrix(elizabethVerbs), 
                        'Darcy': verbsToMatrix(darcyVerbs), 
                        'Jane': verbsToMatrix(janeVerbs)}).fillna(0)
verbsDF.plot(kind='bar', figsize=(14,4))

# %% [markdown]
# # Probabilities
#
# SpaCy has a list of probabilities for English words, and these probabilities are automatically associated with each word once we parse the document. Let's see what the distribution is like:

# %%
probabilities = [word.prob for word in grail] 
pd.Series(probabilities).hist()

# %% [markdown]
# Let's peek at some of the improbable words for _Monty Python and the Holy Grail_.

# %%
list(set([word.string.strip().lower() for word in grail if word.prob < -19]))[:20]
# Out:
# ['',
#  'forest',
#  'again',
#  'camaaaaaargue',
#  'kills',
#  'riding',
#  '#',
#  'cheesy',
#  'own',
#  'mate',
#  'wom',
#  'wound',
#  'dangerous',
#  'treat',
#  'conclusion',
#  'biters',
#  'rheged',
#  'hell',
#  'assist',
#  'that--']

# %% [markdown]
# Now we can do some rudimentary information extraction by counting the improbable words:

# %%
Counter([word.string.strip().lower() 
         for word in grail 
         if word.prob < -19.5]).most_common(20)
# Out:
# [('', 2006),
#  (':', 1197),
#  ('.', 839),
#  ('!', 830),
#  (',', 743),
#  ('the', 332),
#  ('[', 320),
#  (']', 320),
#  ('you', 263),
#  ('arthur', 261),
#  ('i', 240),
#  ('a', 233),
#  ('?', 223),
#  ('and', 184),
#  ('of', 176),
#  ('to', 151),
#  ("'s", 142),
#  ('it', 141),
#  ('no', 129),
#  ('#', 127)]

# %% [markdown]
# What are those words for _Pride and Prejudice_?

# %%
Counter([word.string.strip().lower() 
         for word in pride 
         if word.prob < -19.5 
         and word.is_alpha
         and word.pos_ != 'PROPN'] # This time, let's ignore proper nouns.
       ).most_common(20)
# Out:
# [('the', 4331),
#  ('to', 4160),
#  ('of', 3609),
#  ('and', 3579),
#  ('her', 2224),
#  ('i', 2065),
#  ('a', 1954),
#  ('in', 1880),
#  ('was', 1846),
#  ('she', 1708),
#  ('that', 1576),
#  ('not', 1540),
#  ('it', 1531),
#  ('you', 1357),
#  ('he', 1333),
#  ('his', 1271),
#  ('be', 1240),
#  ('as', 1181),
#  ('had', 1177),
#  ('for', 1058)]

# %% [markdown]
# We can do this with ngrams, too, with some fancy Python magic:

# %%
def ngrams(doc, n): 
    doc = [word for word in doc 
           if word.is_alpha # Get rid of punctuation
           if not word.string.isupper()] # Get rid of all-caps speaker headings
    return list(zip(*[doc[i:] for i in range(n)]))

# %%
grailGrams = set(ngrams(grail, 2))

# %%
for gram in grailGrams: 
     if sum([word.prob for word in gram]) < -20: 
         print(gram)
# Out:
# (in, the)
# (do, us)
# (Launcelot, angels)
# (count, thou)
# (the, questions)
# (me, these)
# (and, tell)
# (this, lot)
# (whop, clunk)
# (This, can)
# (last, words)
# (moistened, bint)
# (Jesus, Christ)
# (It, reads)
# (and, the)
# (please, Lie)
# (squeak, Ooh)
# (Herbert, has)
# (they, put)
# (any, of)
# (do, doubt)
# (Gable, It)
# (bunny, is)
# (What, He)
# (silly, English)
# (Ni, Who)
# (leap, out)
# (castle, with)
# (Grenade, of)
# (seek, the)
# (be, long)
# (is, your)
# (yet, these)
# (bowels, unplugged)
# (Agh, No)
# (Oh, haw)
# (said, the)
# (Oh, Um)
# (you, become)
# (them, here)
# (they, have)
# (foul, cruel)
# (Look, There)
# (it, said)
# (you, mean)
# (Get, on)
# (come, and)
# (handed, Yes)
# (Good, Steady)
# (but, let)
# (all, this)
# (like, her)
# (thonk, Um)
# (your, worst)
# (and, giggle)
# (heard, nothing)
# (back, Come)
# (progress, with)
# (King, of)
# (lot, of)
# (of, other)
# (be, avenged)
# (with, Back)
# (thanks, very)
# (You, liar)
# (accompanied, by)
# (And, so)
# (of, Arimathea)
# (brave, knights)
# (witch, We)
# (name, Bedevere)
# (day, lad)
# (pause, they)
# (Launcelot, Launcelot)
# (out, Once)
# (you, as)
# (the, Holy)
# (leaps, out)
# (sent, you)
# (Sir, Robin)
# (Eh, You)
# (with, it)
# (Here, may)
# (Camelot, Camelot)
# (Do, like)
# (squeak, thump)
# (Burn, her)
# (a, bit)
# (Run, away)
# (Oh, Knights)
# (Oh, yeah)
# (liege, Good)
# (the, Lake)
# (thought, let)
# (from, the)
# (stay, here)
# (singing, He)
# (It, a)
# (is, a)
# (have, accomplished)
# (is, the)
# (do, frighten)
# (in, terrible)
# (a, tree)
# (the, keeper)
# (That, what)
# (remembered, is)
# (Have, at)
# (of, Badon)
# (the, Round)
# (Sir, Robin)
# (us, to)
# (like, the)
# (this, and)
# (temptation, but)
# (one, behold)
# (inherent, in)
# (coconut, on)
# (servant, Sir)
# (in, scene)
# (Right, One)
# (so, yes)
# (him, we)
# (the, French)
# (the, penalty)
# (grenade, that)
# (He, must)
# (exploiting, the)
# (a, system)
# (Round, Table)
# (not, used)
# (getting, better)
# (We, dance)
# (Knights, of)
# (grail, here)
# (into, a)
# (not, assist)
# (got, bad)
# (with, him)
# (questions, three)
# (be, yours)
# (Everything, squeak)
# (witch, witch)
# (Oh, shut)
# (Ni, Ni)
# (chord, Who)
# (It, is)
# (too, perilous)
# (then, lobbest)
# (Aah, boom)
# (on, Back)
# (a, baby)
# (What, are)
# (in, this)
# (sort, of)
# (What, is)
# (me, You)
# (Britons, pause)
# (Shall, Oh)
# (Clear, off)
# (of, full)
# (which, perpetuates)
# (all, the)
# (thud, King)
# (into, the)
# (sing, Arthur)
# (enchanter, of)
# (witches, Burn)
# (time, You)
# (the, swamp)
# (Look, um)
# (Stop, Who)
# (along, Run)
# (Throw, her)
# (someone, it)
# (says, they)
# (blow, thine)
# (to, three)
# (room, Alright)
# (but, from)
# (Knights, of)
# (worthy, Will)
# (sign, that)
# (of, Rheged)
# (off, Right)
# (clank, scribble)
# (we, were)
# (They, just)
# (shall, die)
# (ways, of)
# (squeak, squeak)
# (terrible, peril)
# (going, to)
# (us, voluntarily)
# (tree, in)
# (dappy, English)
# (that, officer)
# (to, be)
# (The, pond)
# (That, are)
# (horse, Yes)
# (those, miserable)
# (want, to)
# (this, sacred)
# (they, We)
# (thwonk, Message)
# (now, go)
# (man, has)
# (the, sign)
# (ha, ha)
# (said, it)
# (more, you)
# (it, Oh)
# (cut, out)
# (Winter, changed)
# (you, do)
# (The, coconut)
# (her, up)
# (Shut, up)
# (singing, stops)
# (no, Oooooooh)
# (music, music)
# (it, Hold)
# (the, decision)
# (the, enchanter)
# (had, nearly)
# (the, pond)
# (Swamp, Castle)
# (people, am)
# (north, from)
# (to, tiny)
# (suspenseful, music)
# (sorry, about)
# (sovereign, of)
# (fight, is)
# (so, ungallant)
# (but, one)
# (to, tell)
# (window, dresser)
# (help, being)
# (Good, Heh)
# (Concorde, um)
# (make, them)
# (a, push)
# (her, Burn)
# (these, things)
# (rewr, rewr)
# (him, What)
# (out, of)
# (does, it)
# (clunk, bang)
# (Winston, Practice)
# (Where, you)
# (when, got)
# (look, have)
# (Dennis, Well)
# (of, weight)
# (much, that)
# (Run, away)
# (an, African)
# (just, a)
# (Ha, ha)
# (you, will)
# (of, the)
# (eh, By)
# (howl, boom)
# (kneeling, We)
# (could, be)
# (of, the)
# (if, the)
# (the, swamp)
# (anywhere, in)
# (cartoon, peril)
# (Oh, please)
# (music, for)
# (joyful, bond)
# (people, bottoms)
# (Chapter, Two)
# (which, Arthur)
# (to, rescue)
# (make, plain)
# (Sir, Launcelot)
# (Well, what)
# (Yes, do)
# (them, And)
# (a, song)
# (way, singing)
# (it, and)
# (that, Did)
# (a, a)
# (We, do)
# (King, Arthur)
# (settles, it)
# (dappy, English)
# (Arthur, was)
# (Galahad, and)
# (count, to)
# (is, thought)
# (it, is)
# (mayhem, Hey)
# (the, Holy)
# (easily, No)
# (of, uuggggggh)
# (Thsss, boom)
# (from, some)
# (de, Loimbard)
# (cheesy, lot)
# (saw, saw)
# (you, have)
# (the, Prince)
# (my, nose)
# (safety, What)
# (Shut, up)
# (You, using)
# (And, sneaking)
# (Grail, Where)
# (No, look)
# (o, land)
# (a, sniff)
# (Ha, ha)
# (is, valiant)
# (Ni, Ni)
# (him, roar)
# (demand, a)
# (come, and)
# (Burn, her)
# (doing, now)
# (your, bottom)
# (than, a)
# (he, fell)
# (me, go)
# (of, the)
# (We, thank)
# (you, get)
# (very, good)
# (sometimes, get)
# (last, words)
# (doubt, your)
# (him, we)
# (has, chosen)
# (saw, saw)
# (Umm, clop)
# (out, your)
# (tackle, us)
# (Run, away)
# (worse, You)
# (Please, Sorry)
# (is, our)
# (Holy, Hand)
# (Oooh, The)
# (awaaaaay, roar)
# (along, Put)
# (please, No)
# (Peril, Oh)
# (ha, spooky)
# (no, Leaving)
# (hacked, and)
# (is, going)
# (bit, Brother)
# (you, join)
# (would, not)
# (now, the)
# (No, auuuuuuuugh)
# (ni, No)
# (consulted, his)
# (We, have)
# (Run, away)
# (were, so)
# (castle, over)
# (the, system)
# (ask, him)
# (that, a)
# (to, die)
# (with, it)
# (the, Bridge)
# (you, do)
# (from, this)
# (plain, the)
# (that, Auuuuuuuugh)
# (haw, Ha)
# (from, the)
# (they, have)
# (Perhaps, And)
# (economic, stress)
# (is, what)
# (Camelot, We)
# (Shall, sir)
# (know, she)
# (to, be)
# (we, are)
# (Hello, Hello)
# (Hmm, boom)
# (peril, Look)
# (saw, saw)
# (to, him)
# (clap, clap)
# (do, know)
# (name, of)
# (this, outrageous)
# (The, Prince)
# (And, there)
# (Will, you)
# (Your, arm)
# (prevent, earthquakes)
# (in, our)
# (He, will)
# (built, a)
# (someone, Stop)
# (Four, shalt)
# (ethereal, music)
# (you, We)
# (no, No)
# (Well, really)
# (Arthur, Arthur)
# (Go, and)
# (a, shrubber)
# (Well, now)
# (valiant, and)
# (us, French)
# (nnniggets, Thpppt)
# (pound, coconut)
# (were, called)
# (Looks, like)
# (Keep, running)
# (for, Schools)
# (Oh, terribly)
# (be, reached)
# (bridgekeeper, am)
# (it, but)
# (good, spanking)
# (No, no)
# (gurgle, There)
# (this, land)
# (Ha, ha)
# (and, sell)
# (a, Saint)
# (Ha, Ha)
# (Camelot, Hurry)
# (anyone, else)
# (middle, path)
# (purest, shimmering)
# (the, first)
# (draw, Come)
# (masses, not)
# (earthquakes, Oh)
# (the, Holy)
# (this, No)
# (done, Aaaugh)
# (join, me)
# (your, ninepence)
# (son, Herbert)
# (Who, Say)
# (What, is)
# (right, we)
# (boom, Look)
# (time, and)
# (scared, to)
# (Ooh, music)
# (no, No)
# (Concorde, Thank)
# (Aah, snap)
# (Very, nice)
# (the, sponge)
# (with, nasty)
# (what, they)
# (that, Brother)
# (Put, him)
# (me, Father)
# (By, anging)
# (Ah, Ohh)
# (leg, off)
# (glass, of)
# (enter, the)
# (No, we)
# (Tale, of)
# (be, praised)
# (Go, and)
# (no, shrubberies)
# (thou, thy)
# (a, witch)
# (and, not)
# (spanking, spanking)
# (until, you)
# (a, witch)
# (may, deal)
# (trade, am)
# (much, You)
# (not, You)
# (am, your)
# (your, Knights)
# (Right, whop)
# (are, delirious)
# (Excuse, me)
# (quest, for)
# (answer, me)
# (does, he)
# (into, the)
# (you, get)
# (Say, Ni)
# (lot, easily)
# (people, groveling)
# (the, Grail)
# (stress, at)
# (them, apart)
# (be, the)
# (Ni, Ni)
# (Cornwall, No)
# (into, the)
# (We, have)
# (splash, Heh)
# (further, for)
# (shrubbery, dramatic)
# (no, no)
# (easily, Oh)
# (ni, Nu)
# (Quick, Please)
# (a, busy)
# (What, happens)
# (Lead, Lead)
# (have, seen)
# (Ni, Ni)
# (Come, Come)
# (Burn, Burn)
# (Prince, Oooh)
# (Launcelot, Galahad)
# (dynamite, Would)
# (single, handed)
# (me, And)
# (else, No)
# (keep, him)
# (taunting, took)
# (this, forest)
# (Yes, sniff)
# (four, which)
# (acting, in)
# (luck, brave)
# (floats, Throw)
# (You, a)
# (Oh, Look)
# (band, whose)
# (right, All)
# (Mercea, The)
# (look, at)
# (problem, It)
# (with, it)
# (Mind, your)
# (those, who)
# (it, again)
# (scared, Look)
# (rock, Perhaps)
# (lose, Gawain)
# (here, He)
# (ha, Heh)
# (quest, for)
# (always, the)
# (you, a)
# (he, all)
# (Shut, up)
# (simple, They)
# (Halt, horn)
# (cough, cough)
# (of, the)
# (this, duck)
# (rewr, music)
# (brave, brave)
# (land, Nothing)
# (Good, Sir)
# (We, got)
# (the, diaphragm)
# (the, sacred)
# (twang, Wayy)
# (You, not)
# (at, Camelot)
# (saw, saw)
# (explain, everything)
# (living, room)
# (Come, on)
# (yes, He)
# (that, No)
# (we, had)
# (him, repressing)
# (what, sad)
# (speed, velocity)
# (they, already)
# (oral, sex)
# (awfully, sorry)
# (note, You)
# (speed, velocity)
# (Well, how)
# (bits, in)
# (Hello, Hello)
# (on, Put)
# (Bring, her)
# (Tale, of)
# (Are, you)
# (Hoo, hoo)
# (art, thou)
# (did, know)
# (Hiyya, Hey)
# (has, got)
# (his, tail)
# (he, will)
# (he, got)
# (fatal, heart)
# (many, a)
# (you, automatically)
# (If, you)
# (a, shrubbery)
# (Run, away)
# (guided, us)
# (Halt, Who)
# (us, Tell)
# (saw, clunk)
# (hee, Hee)
# (ni, again)
# (swallows, although)
# (here, and)
# (had, personally)
# (much, as)
# (see, Right)
# (King, Arthur)
# (Saint, Ives)
# (the, air)
# (in, search)
# (seem, very)
# (my, auntie)
# (Wait, a)
# (fooling, anyone)
# (not, a)
# (questions, may)
# (your, quest)
# (with, your)
# (no, arms)
# (you, doing)
# (someone, else)
# (this, land)
# (Who, Say)
# (killer, Get)
# (my, note)
# (idea, Lord)
# (Right, Yeah)
# (Ow, Agh)
# (keen, Uh)
# (clunk, Jesus)
# (down, fell)
# (stops, Is)
# (seen, the)
# (duck, Use)
# (Grail, There)
# (an, emperor)
# (all, the)
# (That, what)
# (mumble, boom)
# (no, no)
# (your, dead)
# (and, then)
# (had, discovered)
# (Yes, my)
# (Please, please)
# (long, long)
# (Knight, of)
# (basic, medical)
# (spank, me)
# (a, happy)
# (It, may)
# (boom, Ayy)
# (Heh, Looks)
# (look, What)
# (up, will)
# (With, footwork)
# (through, good)
# (here, and)
# (we, not)
# (handsome, knight)
# (King, of)
# (Hold, it)
# (yes, it)
# (Well, what)
# (hopeless, when)
# (and, quiet)
# (he, is)
# (saw, it)
# (got, a)
# (clop, clop)
# (your, own)
# (to, marry)
# (Hold, it)
# (knees, bent)
# (sight, shall)
# (it, Hurry)
# (liege, Consult)
# (hospital, Ahh)
# (my, court)
# (am, your)
# (you, burn)
# (do, you)
# (really, can)
# (he, seemed)
# (sloths, and)
# (to, us)
# (naughty, person)
# (wood, sink)
# (the, ways)
# (am, In)
# (do, Anyway)
# (do, nibble)
# (yourself, We)
# (peril, do)
# (sheep, bladders)
# (He, going)
# (shrubberies, Ni)
# (Shh, Shh)
# (pikang, zoop)
# (you, sure)
# (go, back)
# (of, Ni)
# (want, to)
# (relics, Brother)
# (wishes, me)
# (You, said)
# (the, Holy)
# (think, this)
# (Right, Arthur)
# (a, coconut)
# (You, have)
# (away, or)
# (can, tackle)
# (Bors, That)
# (Right, All)
# (mine, kneeling)
# (brave, brave)
# (thud, scrape)
# (food, trough)
# (Stop, that)
# (Lake, angels)
# (and, bad)
# (a, lot)
# (sing, Stop)
# (Death, He)
# (a, favor)
# (this, is)
# (pound, pound)
# (let, me)
# (Would, you)
# (ha, Hey)
# (clap, clap)
# (on, We)
# (body, burned)
# (is, grail)
# (my, liege)
# (she, must)
# (Stop, it)
# (Dennis, there)
# (good, pig)
# (of, man)
# (etc, and)
# (me, no)
# (To, the)
# (Let, go)
# (See, you)
# (until, come)
# (the, Castle)
# (these, are)
# (Who, are)
# (met, Launcelot)
# (Castle, of)
# (the, sun)
# (son, of)
# (them, an)
# (she, is)
# (Stop, that)
# (shall, use)
# (handle, us)
# (tree, with)
# (Right, But)
# (at, least)
# (seen, it)
# (In, Mercea)
# (Arthur, music)
# (that, leads)
# (Very, well)
# (boom, Ay)
# (Grail, Heh)
# (what, a)
# (who, had)
# (you, a)
# (Cut, that)
# (so, much)
# (a, second)
# (idiom, sometimes)
# (pack, that)
# (Yes, get)
# (Burn, her)
# (word, Surely)
# (sir, Farewell)
# (me, am)
# (No, you)
# (who, wishes)
# (sir, He)
# (it, singing)
# (types, burst)
# (cave, a)
# (Aaaaaah, Aaaaaaaaah)
# (arm, off)
# (food, and)
# (And, you)
# (were, with)
# (long, way)
# (up, on)
# (persons, taunting)
# (ha, hee)
# (out, your)
# (any, swallows)
# (not, dead)
# (of, where)
# (of, course)
# (away, eh)
# (were, in)
# (Run, away)
# (is, the)
# (requiem, Pie)
# (up, Perhaps)
# (husk, It)
# (swamp, So)
# (squeak, All)
# (Ni, The)
# (be, the)
# (It, good)
# (naughty, in)
# (a, wart)
# (Sir, Launcelot)
# (ha, Ha)
# (music, thud)
# (gay, No)
# (your, leg)
# (supports, whop)
# (and, tell)
# (whose, father)
# (that, old)
# (your, king)
# (Mmm, nice)
# (to, be)
# (that, then)
# (or, anyone)
# (could, bring)
# (clunk, Come)
# (Oh, wicked)
# (it, too)
# (uh, make)
# (Ohh, Right)
# (goodem, zoo)
# (of, coconut)
# (pound, pound)
# (as, to)
# (man, had)
# (meant, the)
# (boom, mumble)
# (me, to)
# (or, the)
# (cost, me)
# (triumphs, Have)
# (Arthur, the)
# (haw, haw)
# (cave, lies)
# (am, ready)
# (off, Now)
# (with, her)
# (the, water)
# (disheartened, King)
# (in, and)
# (talk, to)
# (get, a)
# (We, eat)
# (Sir, Launcelot)
# (the, last)
# (Dramatically, sir)
# (Idiom, No)
# (Oh, Oooo)
# (Did, you)
# (gouged, out)
# (great, peril)
# (me, Uh)
# (say, sorry)
# (and, giggle)
# (now, lads)
# (quest, To)
# (hee, hee)
# (again, That)
# (yet, dappy)
# (have, a)
# (and, a)
# (Knights, Knights)
# (trough, wiper)
# (and, must)
# (business, If)
# (Auuuuuuuugh, How)
# (here, Now)
# (Not, at)
# (the, Britons)
# (from, the)
# (a, very)
# (clop, clop)
# (Bring, out)
# (a, second)
# (We, are)
# (call, me)
# (Why, does)
# (Quite, indefatigable)
# (happy, feel)
# (it, in)
# (signifying, by)
# (shall, snuff)
# (Lord, Course)
# (had, lobbed)
# (Burn, her)
# (since, her)
# (Until, come)
# (Oh, what)
# (the, finest)
# (Britain, but)
# (He, killed)
# (We, knights)
# (sell, shrubberies)
# (back, Eee)
# (Come, on)
# (make, sure)
# (and, sloths)
# (it, again)
# (The, Lady)
# (they, did)
# (make, castanets)
# (him, when)
# (No, Ni)
# (we, call)
# (it, not)
# (And, what)
# (you, Thank)
# (him, Oh)
# (not, my)
# (drink, Well)
# (the, behind)
# (lovely, filth)
# (only, people)
# (the, purest)
# (are, you)
# (cry, of)
# (system, Help)
# (Yes, Oh)
# (Oh, shit)
# (rescue, me)
# (imprisoned, by)
# (sir, Most)
# (want, We)
# (Shh, Shh)
# (does, leave)
# (enjoying, this)
# (to, scene)
# (reasonable, Fetchez)
# (get, him)
# (also, make)
# (dark, forest)
# (marry, against)
# (And, chickening)
# (warned, you)
# (does, it)
# (Hah, Bloody)
# (it, That)
# (and, the)
# (in, this)
# (land, through)
# (of, splat)
# (We, kill)
# (the, Knights)
# (It, not)
# (Hold, it)
# (boom, boom)
# (the, Bridge)
# (my, teeth)
# (them, my)
# (of, the)
# (Launcelot, Launcelot)
# (must, speak)
# (you, like)
# (to, old)
# (God, Hoo)
# (Hello, Hello)
# (rescue, me)
# (Britons, defeator)
# (it, Ohh)
# (Robin, His)
# (hee, Ha)
# (the, room)
# (Well, you)
# (voluntarily, ni)
# (used, to)
# (How, many)
# (to, join)
# (Yes, Yes)
# (Right, Hic)
# (That, it)
# (knights, went)
# (is, it)
# (the, trouble)
# (need, all)
# (Oh, yeah)
# (escape, more)
# (It, a)
# (a, shrubbery)
# (How, do)
# (hast, vouchsafed)
# (thing, ca)
# (that, King)
# (of, her)
# (sure, e)
# (uh, like)
# (where, we)
# (other, side)
# (at, your)
# (you, Man)
# (we, glad)
# (you, mean)
# (evil, Zoot)
# (to, the)
# (of, the)
# (real, Grail)
# (have, no)
# (makes, you)
# (and, brunettes)
# (know, that)
# (it, It)
# (Aaaugh, etc)
# (as, a)
# (tell, Oh)
# (long, No)
# (show, us)
# (union, of)
# (of, the)
# (vests, and)
# (got, my)
# (He, is)
# (or, European)
# (attack, at)
# (lot, at)
# (would, knew)
# (now, Well)
# (quiet, Order)
# (the, Dragon)
# (we, have)
# (There, is)
# (and, his)
# (squeak, squeak)
# (It, ca)
# (bride, father)
# (of, Uther)
# (Come, and)
# (amazes, me)
# (push, the)
# (her, Quiet)
# (us, How)
# (must, rest)
# (squeak, squeak)
# (the, hand)
# (Forgive, me)
# (you, going)
# (No, Not)
# (search, for)
# (knocked, through)
# (All, right)
# (compared, to)
# (up, And)
# (testicles, already)
# (you, Splendid)
# (There, Look)
# (are, you)
# (his, bowels)
# (to, leave)
# (right, through)
# (my, liege)
# (the, knights)
# (been, for)
# (Right, We)
# (there, thirty)
# (grail, shaped)
# (No, You)
# (baby, ca)
# (scribble, scribble)
# (ill, getting)
# (me, Yes)
# (Ives, Oh)
# (One, two)
# (Autumn, Aah)
# (her, Do)
# (Ni, Ni)
# (Father, do)
# (Oh, he)
# (see, By)
# (ha, Where)
# (come, and)
# (into, Winter)
# (now, no)
# (uh, living)
# (Hic, Ah)
# (my, trusty)
# (dead, Prince)
# (ha, ha)
# (lair, So)
# (more, Be)
# (are, We)
# (music, just)
# (who, killed)
# (into, Summer)
# (clap, clap)
# (dictatorship, self)
# (your, dead)
# (Crapper, and)
# (tragic, death)
# (upon, the)
# (eh, Look)
# (the, blood)
# (cave, which)
# (Bridge, of)
# (bathing, dressing)
# (the, plover)
# (thank, you)
# (thy, mercy)
# (Now, he)
# (you, Shall)
# (master, if)
# (sequin, vests)
# (from, scene)
# (quest, for)
# (pound, Open)
# (Right, We)
# (question, of)
# (three, no)
# (pulp, Or)
# (here, and)
# (Yeah, Yup)
# (angels, sing)
# (very, brave)
# (Yes, you)
# (your, dead)
# (am, in)
# (This, could)
# (teeth, Oh)
# (invincible, You)
# (setting, alight)
# (Come, this)
# (donaeis, requiem)
# (Anybody, armed)
# (do, zoosh)
# (me, invincible)
# (twenty, four)
# (of, all)
# (come, on)
# (wind, clop)
# (You, not)
# (Hah, clunk)
# (to, stand)
# (Shut, your)
# (runes, upon)
# (How, Well)
# (if, they)
# (Bring, out)
# (Burn, her)
# (want, you)
# (you, known)
# (the, name)
# (French, persons)
# (covered, Too)
# (quest, To)
# (in, my)
# (internal, Be)
# (one, am)
# (Oh, wicked)
# (busy, life)
# (her, well)
# (And, me)
# (time, we)
# (to, that)
# (looking, for)
# (thy, foe)
# (found, them)
# (us, all)
# (been, setting)
# (grip, it)
# (repressing, me)
# (shall, pass)
# (Make, sure)
# (this, This)
# (yeah, True)
# (Running, away)
# (a, a)
# (Camelot, to)
# (a, third)
# (blessing, blessing)
# (wind, saw)
# (who, being)
# (Death, The)
# (five, Three)
# (minutes, He)
# (We, have)
# (escape, Excuse)
# (sawwwww, clunk)
# (the, Holy)
# (can, hear)
# (do, good)
# (ways, of)
# (left, Yes)
# (in, water)
# (Right, Oh)
# (retreat, All)
# (fell, over)
# (be, someone)
# (Therefore, we)
# (her, Burn)
# (shit, We)
# (Death, Oh)
# (Ni, Ni)
# (color, Blue)
# (No, it)
# (were, still)
# (Burn, her)
# (the, Pure)
# (decided, that)
# (Thank, you)
# (a, great)
# (does, matter)
# (What, Have)
# (ridden, the)
# (the, pond)
# (boom, angels)
# (live, Hee)
# (Launcelot, police)
# (from, just)
# (fooling, yourself)
# (That, settles)
# (Uhh, Does)
# (right, You)
# (beat, its)
# (had, enough)
# (and, biscuits)
# (mumble, mumble)
# (are, you)
# (saved, at)
# (As, the)
# (foe, who)
# (Where, is)
# (we, run)
# (guards, Uh)
# (Oh, certainly)
# (times, Good)
# (Ay, up)
# (You, fight)
# (Course, it)
# (lovely, acting)
# (get, him)
# (us, single)
# (take, this)
# (occasion, Let)
# (it, again)
# (Good, luck)
# (sir, later)
# (me, they)
# (Uh, he)
# (example, in)
# (shall, watch)
# (you, a)
# (the, Tall)
# (up, Stop)
# (you, uh)
# (He, going)
# (a, witch)
# (into, a)
# (shaped, beacon)
# (are, the)
# (accomplished, a)
# (eat, Robin)
# (pweeng, boom)
# (Arthur, music)
# (Arthur, music)
# (King, of)
# (up, like)
# (here, squeak)
# (Hmm, boom)
# (burned, off)
# (the, first)
# (you, You)
# (new, strategy)
# (been, imprisoned)
# (squeak, squeak)
# (and, face)
# (to, tell)
# (that, word)
# (approaching, any)
# (are, We)
# (Huyah, clang)
# (along, Everything)
# (Schools, take)
# (Hurry, Sir)
# (large, Skip)
# (his, that)
# (am, king)
# (Allo, dappy)
# (one, more)
# (that, what)
# (liege, Good)
# (much, That)
# (varletesses, The)
# (question, of)
# (and, we)
# (Ow, Ow)
# (to, which)
# (you, do)
# (What, is)
# (just, keep)
# (it, Yes)
# (bicker, and)
# (your, every)
# (bit, bit)
# (and, see)
# (be, nice)
# (keep, him)
# (No, Knights)
# (clank, have)
# (The, Black)
# (stops, Aaagh)
# (Good, idea)
# (that, suit)
# (clop, clop)
# (What, object)
# (do, want)
# (listen, to)
# (last, minute)
# (Black, Beast)
# (her, Burn)
# (Ni, Ow)
# (deal, with)
# (there, was)
# (scene, with)
# (the, Holy)
# (properly, No)
# (one, That)
# (by, a)
# (you, empty)
# (get, on)
# (may, become)
# (in, Camelot)
# (to, handsome)
# (is, the)
# (We, are)
# (when, your)
# (uh, and)
# (is, Agh)
# (We, did)
# (round, table)
# (Ohh, Do)
# (away, Run)
# (leap, look)
# (have, brought)
# (Ah, thanks)
# (lord, We)
# (No, and)
# (Christ, thud)
# (course, The)
# (agree, with)
# (on, Thursday)
# (very, nice)
# (join, King)
# (design, shrubberies)
# (capital, of)
# (Hand, Grenade)
# (her, Right)
# (hall, We)
# (up, singing)
# (Burn, her)
# (were, more)
# (in, these)
# (nice, of)
# (sneaking, away)
# (cross, that)
# (lad, all)
# (ai, heard)
# (rather, music)
# (kick, Look)
# (covered, this)
# (but, you)
# (who, had)
# (forget, about)
# (But, Father)
# (there, a)
# (He, going)
# (her, Burn)
# (a, a)
# (No, not)
# (liege, It)
# (Three, sir)
# (What, wrong)
# (will, you)
# (about, the)
# (with, that)
# (only, a)
# (the, name)
# (mooo, If)
# (feel, sure)
# (the, Britons)
# (Burn, her)
# (by, for)
# (away, and)
# (Arthur, King)
# (Ni, Ni)
# (scenes, With)
# (That, is)
# (for, you)
# (imperialist, dogma)
# (music, stops)
# (can, we)
# (call, cry)
# (is, sneaking)
# (coconuts, What)
# (non, migratory)
# (perpetuates, the)
# (of, uuggggggh)
# (him, thud)
# (Ni, Ni)
# (Do, be)
# (bent, running)
# (can, And)
# (try, to)
# (Sir, Launcelot)
# (in, which)
# (Ni, we)
# (flight, away)
# (scribble, scribble)
# (off, Yes)
# (Yes, Let)
# (you, What)
# (of, the)
# (who, The)
# (ha, ha)
# (You, got)
# (is, your)
# (me, in)
# (people, would)
# (how, do)
# (rewr, squeak)
# (spanked, her)
# (Walk, away)
# (French, Why)
# (is, a)
# (want, to)
# (What, is)
# (Angnor, who)
# (suffered, much)
# (about, to)
# (the, most)
# (mandate, from)
# (looks, like)
# (have, all)
# (off, And)
# (you, better)
# (What, does)
# (Yes, Oh)
# (who, is)
# (a, dictatorship)
# (room, There)
# (away, and)
# (Well, why)
# (ca, just)
# (Ahh, Summer)
# (cut, his)
# (mumble, mumble)
# (Pull, that)
# (scene, Get)
# (it, and)
# (Holy, Grail)
# (of, King)
# (old, woman)
# (must, cut)
# (taunt, it)
# (wood, And)
# (It, against)
# (live, in)
# (eight, wedding)
# (ways, Sir)
# (we, could)
# (see, the)
# (a, give)
# (your, son)
# (in, the)
# (from, the)
# (find, a)
# (eyes, on)
# (happy, whop)
# (that, is)
# (courage, or)
# (Brave, Sir)
# (It, a)
# (want, singing)
# (requiem, Pie)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# (yes, Let)
# (are, tired)
# (her, as)
# (of, Bristol)
# (The, oral)
# (back, into)
# (bats, and)
# (Run, away)
# (if, you)
# (Use, this)
# (Oooh, ptoo)
# (Camelot, pause)
# (note, have)
# (that, castle)
# (but, other)
# (what, do)
# (for, our)
# (who, hear)
# (there, must)
# (really, did)
# (witness, the)
# (going, to)
# (know, so)
# (sad, So)
# (islands, But)
# (her, He)
# (Are, you)
# (then, proceed)
# (ha, Charge)
# (ni, You)
# (minute, How)
# (on, with)
# (build, a)
# (Ooh, All)
# (away, Run)
# (be, a)
# (well, actually)
# (Speak, to)
# (the, middle)
# (Knights, of)
# (for, death)
# (There, no)
# (always, triumphs)
# (large, wooden)
# (his, feet)
# (four, really)
# (splat, crying)
# (relax, Are)
# (under, the)
# (anyway, Right)
# (Anthrax, The)
# (up, Well)
# (already, got)
# (Mine, is)
# (is, your)
# (ha, we)
# (Oh, wicked)
# (Oh, let)
# (Sir, Gallahad)
# (We, will)
# (excepting, that)
# (questions, Three)
# (chorus, scenes)
# (can, not)
# (Yes, think)
# (mean, An)
# (Britons, to)
# (head, he)
# (in, that)
# (sink, in)
# (kicked, the)
# (busy, man)
# (tell, us)
# (mean, just)
# (to, Twenty)
# (the, Grail)
# (shall, attack)
# (Pie, Iesu)
# (By, what)
# (Oh, you)
# (Oh, no)
# (Yes, of)
# (give, you)
# (of, Camelot)
# (she, got)
# (tell, your)
# (Doctor, Piglet)
# (of, the)
# (so, brave)
# (the, legendary)
# (scratch, Your)
# (worthy, boom)
# (But, then)
# (Leaving, the)
# (to, me)
# (me, what)
# (down, here)
# (take, it)
# (stretched, out)
# (one, big)
# (away, No)
# (What, does)
# (In, the)
# (my, liege)
# (to, join)
# (was, not)
# (spoken, in)
# (mean, You)
# (economic, and)
# (King, of)
# (Go, on)
# (enchanter, of)
# (about, advancing)
# (better, Burn)
# (bonk, witch)
# (rewr, rewr)
# (Ni, Ni)
# (say, ni)
# (know, you)
# (real, and)
# (they, had)
# (out, your)
# (bravely, turned)
# (the, idea)
# (you, to)
# (find, the)
# (Hang, on)
# (you, pansy)
# (and, get)
# (dull, and)
# (but, not)
# (of, purely)
# (clap, clap)
# (will, beat)
# (this, kingdom)
# (Eternal, Peril)
# (to, go)
# (He, is)
# (Sir, Robin)
# (stay, here)
# (is, your)
# (weekly, Yes)
# (off, Yes)
# (Oh, yes)
# (sorry, Sorry)
# (questions, He)
# (brave, Sir)
# (The, Grail)
# (must, return)
# (these, woods)
# (He, has)
# (his, liver)
# (Knight, of)
# (Galahad, Oh)
# (the, biggest)
# (Hic, Right)
# (Go, on)
# (It, not)
# (Yeah, Yes)
# (you, all)
# (us, all)
# (say, we)
# (shrubbery, May)
# (find, out)
# (dare, you)
# (Well, what)
# (splash, Ho)
# (trouble, They)
# (knights, if)
# (on, music)
# (of, elderberries)
# (his, bottom)
# (to, be)
# (can, explain)
# (singing, He)
# (two, five)
# (scenes, think)
# (Three, And)
# (Together, they)
# (Stop, that)
# (second, one)
# (finds, this)
# (given, up)
# (say, one)
# (sort, of)
# (for, attack)
# (more, Oh)
# (for, the)
# (Dis, mount)
# (Burn, her)
# (do, think)
# (It, not)
# (show, It)
# (along, Pull)
# (to, maintain)
# (stone, dead)
# (Let, him)
# (no, man)
# (Who, Say)
# (more, The)
# (Death, must)
# (things, when)
# (the, very)
# (me, To)
# (angels, sing)
# (Sir, Galahad)
# (if, you)
# (Well, you)
# (k, niggets)
# (knight, live)
# (again, to)
# (later, wind)
# (be, employed)
# (town, where)
# (some, who)
# (the, other)
# (sir, fwump)
# (Charge, squeak)
# (Go, away)
# (some, farcical)
# (castle, seems)
# (Let, him)
# (can, not)
# (side, he)
# (of, your)
# (have, been)
# (Just, keep)
# (Ages, Umhm)
# (your, dead)
# (the, Holy)
# (the, house)
# (an, example)
# (in, and)
# (surprise, and)
# (this, wood)
# (curtains, No)
# (a, note)
# (Thank, you)
# (frighten, us)
# (killed, in)
# (a, sacrifice)
# (working, Oh)
# (much, rejoicing)
# (We, shall)
# (lying, in)
# (quack, quack)
# (to, be)
# (What, the)
# (kick, Right)
# (over, him)
# (Ni, Ni)
# (think, Is)
# (got, better)
# (your, own)
# (Burn, Burn)
# (Hya, Hiyya)
# (We, are)
# (must, be)
# (Arthur, King)
# (Just, uuggggggh)
# (yes, Oh)
# (stops, silence)
# (just, passing)
# (if, ye)
# (do, you)
# (Stop, it)
# (trumpets, Camelot)
# (Nu, No)
# (at, me)
# (Hello, Hello)
# (swallow, carrying)
# (to, the)
# (how, did)
# (kingdom, of)
# (the, fourth)
# (Lord, God)
# (Camelot, What)
# (ratios, five)
# (to, build)
# (shalt, thou)
# (Aagh, As)
# (rewr, rewr)
# (going, seek)
# (bit, of)
# (a, vital)
# (Are, you)
# (Sir, Robin)
# (arrange, and)
# (to, go)
# (else, up)
# (all, the)
# (of, the)
# (and, there)
# (Bridge, of)
# (quiet, But)
# (angels, sing)
# (all, They)
# (tell, He)
# (attack, Ulk)
# (good, name)
# (Man, Well)
# (tell, the)
# (people, in)
# (changed, back)
# (it, Yes)
# (away, Run)
# (that, Auuuuuuuugh)
# (Oooo, trumpets)
# (for, a)
# (Gallahad, the)
# (Sir, Knight)
# (Knights, Who)
# (swallow, maybe)
# (in, the)
# (bad, person)
# (going, into)
# (meant, him)
# (you, kill)
# (sneaking, away)
# (Yes, Lord)
# (Arthur, this)
# (Ni, Then)
# (There, are)
# (no, man)
# (your, son)
# (we, are)
# (formidable, But)
# (Well, he)
# (They, could)
# (So, they)
# (to, Camelot)
# (First, shalt)
# (He, asks)
# (clop, boom)
# (warm, and)
# (his, head)
# (Quiet, There)
# (God, we)
# (Oh, but)
# (Ecky, ecky)
# (Lord, we)
# (Look, it)
# (Hyy, Hya)
# (Aaagh, Ooh)
# (did, And)
# (you, Away)
# (tough, and)
# (the, nick)
# (the, bride)
# (for, the)
# (that, it)
# (him, like)
# (have, Look)
# (ran, away)
# (boom, Hello)
# (away, Run)
# (the, Holy)
# (Grail, Our)
# (Sir, Lancelot)
# (my, liege)
# (dead, rewr)
# (no, Aauuuuugh)
# (England, Mind)
# (may, be)
# (Um, woosh)
# (kill, all)
# (to, tell)
# (crash, clang)
# (your, door)
# (about, his)
# (chance, English)
# (Get, on)
# (stew, comin)
# (to, Camelot)
# (boom, clap)
# (running, boom)
# (think, you)
# (clop, clop)
# (favor, What)
# (with, it)
# (Holy, Grail)
# (Excalibur, singing)
# (ha, And)
# (how, we)
# (So, how)
# (not, a)
# (to, recover)
# (flint, or)
# (off, Come)
# (He, going)
# (Launcelot, Galahad)
# (sacred, quest)
# (then, sank)
# (Well, Well)
# (that, thou)
# (Shut, up)
# (have, it)
# (you, must)
# (pig, country)
# (when, passing)
# (Britons, Who)
# (cast, into)
# (handed, Yes)
# (we, have)
# (not, carry)
# (order, you)
# (You, do)
# (thou, two)
# (quest, To)
# (we, given)
# (head, Oh)
# (the, door)
# (That, the)
# (heh, Oh)
# (creep, No)
# (running, about)
# (chord, roar)
# (does, he)
# (of, more)
# (getting, better)
# (Ni, Shh)
# (My, liege)
# (living, rock)
# (stop, our)
# (on, with)
# (here, today)
# (Grenade, chanting)
# (to, carve)
# (best, you)
# (away, Run)
# (Wayy, splash)
# (own, head)
# (domine, dona)
# (keep, him)
# (you, sir)
# (every, need)
# (Sir, Launcelot)
# (carries, with)
# (Well, ask)
# (Maynard, Bring)
# (to, cost)
# (Armaments, Chapter)
# (aaggggh, He)
# (Yes, Make)
# (strategy, was)
# (bid, you)
# (ha, ha)
# (of, Death)
# (to, me)
# (will, not)
# (not, doing)
# (now, uh)
# (No, not)
# (Stop, saying)
# (count, and)
# (taking, the)
# (rabbit, dynamite)
# (ha, And)
# (any, progress)
# (can, defeat)
# (a, model)
# (of, open)
# (everything, Do)
# (carried, away)
# (can, not)
# (on, high)
# (knights, seemed)
# (of, an)
# (carried, What)
# (first, and)
# (no, such)
# (logically, If)
# (recover, suddenly)
# (him, Oh)
# (And, we)
# (Pie, Iesu)
# (make, a)
# (Brave, brave)
# (what, carved)
# (Oh, Please)
# (seek, the)
# (Shut, up)
# (held, under)
# (On, y)
# (All, right)
# (Robin, singing)
# (Sir, Robin)
# (else, Just)
# (could, uh)
# (a, chance)
# (go, and)
# (you, no)
# (witch, witch)
# (Until, you)
# (Ha, ha)
# (Oh, come)
# (he, said)
# (more, no)
# (right, All)
# (Away, away)
# (king, you)
# (clang, Bring)
# (depressing, Now)
# (swallows, flights)
# (performance, clop)
# (got, one)
# (Heh, heh)
# (pull, through)
# (the, Castle)
# (centuries, the)
# (Hello, Hello)
# (You, would)
# (It, was)
# (Launcelot, of)
# (could, buy)
# (he, see)
# (brave, Sir)
# (brave, Sir)
# (vache, mooo)
# (Um, look)
# (ready, Would)
# (on, into)
# (the, not)
# (the, workers)
# (nothing, wrong)
# (you, see)
# (is, to)
# (tell, us)
# (purpose, Arthur)
# (the, five)
# (you, could)
# (last, call)
# (singing, But)
# (was, to)
# (one, to)
# (burned, down)
# (sure, e)
# (look, upon)
# (down, the)
# (Run, away)
# (Look, can)
# (today, to)
# (the, fight)
# (the, Knights)
# (out, uh)
# (wanna, talk)
# (pound, pound)
# (fatal, wounding)
# (is, far)
# (the, castle)
# (the, enchanter)
# (warned, you)
# (found, the)
# (and, let)
# (them, seldom)
# (much, about)
# (you, bite)
# (south, with)
# (And, his)
# (You, must)
# (third, one)
# (a, shrubbery)
# (What, is)
# (up, the)
# (Well, we)
# (tit, soiled)
# (Aaaah, slash)
# (Oh, yeah)
# (taunting, We)
# (will, take)
# (cop, Burn)
# (an, autonomous)
# (castle, No)
# (African, swallows)
# (French, uh)
# (wise, in)
# (and, uh)
# (to, be)
# (killed, the)
# (and, pissing)
# (Well, what)
# (the, er)
# (there, was)
# (chosen, Ha)
# (but, you)
# (heh, heh)
# (out, rewr)
# (twenty, four)
# (actually, am)
# (away, away)
# (the, forest)
# (a, feint)
# (No, they)
# (not, say)
# (in, the)
# (the, right)
# (eis, requiem)
# (You, were)
# (And, this)
# (a, creature)
# (heh, heh)
# (you, go)
# (can, ni)
# (and, Ni)
# (duck, Oooh)
# (witch, Yeah)
# (afraid, our)
# (You, are)
# (join, me)
# (flesh, wound)
# (elbows, broken)
# (nothing, really)
# (bit, daft)
# (soiled, my)
# (Brave, Sir)
# (Uh, well)
# (rewr, clang)
# (dancing, In)
# (think, was)
# (Oh, do)
# (Fine, Um)
# (music, music)
# (doctors, immediately)
# (Thank, you)
# (singing, He)
# (most, Holy)
# (swallow, Huh)
# (Fiends, tear)
# (her, Burn)
# (Hello, Hello)
# (van, Get)
# (that, boom)
# (newt, got)
# (twong, baaaa)
# (by, Divine)
# (They, dressed)
# (yours, We)
# (main, hall)
# (approacheth, the)
# (one, Uuh)
# (grin, and)
# (it, Aaaaugh)
# (No, now)
# (your, dead)
# (not, more)
# (bonk, dona)
# (appearing, in)
# (idea, Behold)
# (course, Joseph)
# (less, Three)
# (Shut, up)
# (No, no)
# (we, able)
# (ooh, Have)
# (when, the)
# (open, the)
# (Launcelot, Launcelot)
# (task, to)
# (no, more)
# (Um, oo)
# (Back, Get)
# (room, No)
# (in, a)
# (Order, eh)
# (Welcome, gentle)
# (uuggggggh, What)
# (stab, Aagh)
# (Guy, de)
# (this, is)
# (Monsieur, Arthur)
# (soon, to)
# (he, chickened)
# (daft, to)
# (Summer, changed)
# (Right, Oh)
# (you, and)
# (here, Oh)
# (then, have)
# (so, understanding)
# (will, say)
# (sing, boom)
# (continue, gurgle)
# (We, coming)
# (it, That)
# (of, the)
# (My, liege)
# (Oh, Waa)
# (Three, sir)
# (crash, Hoo)
# (see, What)
# (burn, pause)
# (Mercea, Where)
# (Exactly, So)
# (were, in)
# (is, one)
# (spake, saying)
# (but, she)
# (Well, you)
# (Are, there)
# (Run, away)
# (by, surprise)
# (Run, away)
# (he, bravely)
# (back, Get)
# (your, quest)
# (a, scholar)
# (Grail, boom)
# (Ha, ha)
# (Like, what)
# (biscuits, Yes)
# (nervous, sire)
# (me, the)
# (you, tell)
# (God, and)
# (against, regulations)
# (been, charged)
# (it, again)
# (Behold, the)
# (Lancelot, the)
# (Did, you)
# (was, so)
# (in, the)
# (Round, Table)
# (And, after)
# (you, go)
# (king, then)
# (be, so)
# (Oh, Yes)
# (the, tops)
# (known, There)
# (master, Guy)
# (mean, to)
# (right, out)
# (ere, the)
# (her, Burn)
# (obviously, But)
# (Run, away)
# (have, been)
# (away, Oh)
# (Forward, boom)
# (valor, for)
# (Well, it)
# (squeak, Aaaaugh)
# (Oh, Come)
# (certain, special)
# (the, penalty)
# (He, who)
# (right, howl)
# (arms, left)
# (Pie, Iesu)
# (diaphragm, a)
# (by, surprise)
# (a, basic)
# (Holy, Grail)
# (of, Death)
# (Hang, on)
# (dead, clang)
# (and, you)
# (English, pig)
# (my, trade)
# (Summer, a)
# (we, tough)
# (a, Knight)
# (the, Grail)
# (by, the)
# (Sir, Launcelot)
# (argue, about)
# (how, does)
# (Ooh, Come)
# (Ow, Oh)
# (Well, that)
# (dead, Since)
# (Burn, Burn)
# (when, you)
# (opening, request)
# (rrrr, rrrr)
# (uh, Launcelot)
# (plan, sir)
# (is, made)
# (At, once)
# (slightly, higher)
# (wave, my)
# (leave, The)
# (the, Holy)
# (wherein, carved)
# (Where, There)
# (you, to)
# (sure, he)
# (afraid, to)
# (spooky, music)
# (and, his)
# (easily, Yes)
# (and, the)
# (Castle, Anthrax)
# (and, get)
# (chance, been)
# (on, Clear)
# (Nothing, Here)
# (you, ever)
# (Action, Defeat)
# (Tim, Quite)
# (Not, at)
# (a, good)
# (France, think)
# (rrrr, rrrr)
# (the, brave)
# (into, the)
# (Holy, Grail)
# (traveller, five)
# (then, had)
# (penalty, And)
# (You, are)
# (Launcelot, Launcelot)
# (leave, Oh)
# (country, Is)
# (my, court)
# (medieval, hall)
# (shaped, It)
# (dead, Ere)
# (carved, in)
# (to, my)
# (away, Thppppt)
# (something, you)
# (ever, going)
# (you, then)
# (your, aunties)
# (ordinary, rabbit)
# (you, Clear)
# (Oh, see)
# (aside, worthy)
# (which, is)
# (words, of)
# (we, thank)
# (coconut, tropical)
# (parts, at)
# (questions, bridgekeeper)
# (smashed, in)
# (separate, and)
# (better, get)
# (the, Holy)
# (of, the)
# (has, ever)
# (no, Oh)
# (fair, cop)
# (Holy, Grail)
# (her, What)
# (It, better)
# (Oh, yes)
# (does, leave)
# (get, that)
# (By, a)
# (other, illustrious)
# (at, this)
# (for, the)
# (so, much)
# (the, name)
# (enough, Just)
# (brave, as)
# (Ohh, That)
# (Where, that)
# (you, suggesting)
# (again, how)
# (each, of)
# (on, with)
# (dramatic, chord)
# (commands, then)
# (saved, Sir)
# (do, witches)
# (to, someone)
# (Hand, Grenade)
# (Himself, has)
# (off, Victory)
# (are, the)
# (have, found)
# (him, You)
# (that, No)
# (We, lost)
# (rabbit, You)
# (to, cut)
# (the, keepers)
# (Be, quiet)
# (the, previous)
# (no, No)
# (um, riding)
# (went, round)
# (Who, are)
# (at, all)
# (open, the)
# (hee, hee)
# (a, harmless)
# (Oooh, My)
# (is, the)
# (person, Now)
# (broken, To)
# (same, always)
# (feel, happy)
# (Grail, Well)
# (unladen, swallow)
# (foul, so)
# (each, Well)
# (Sir, Robin)
# (Go, away)
# (What, is)
# (tell, Come)
# (away, had)
# (singing, Bravely)
# (well, excuse)
# (rocks, Cider)
# (in, which)
# (we, will)
# (Look, on)
# (ever, set)
# (She, has)
# (very, dull)
# (rejoicing, Yay)
# (and, cut)
# (Aauuggghhh, Aaauggh)
# (mumble, boom)
# (there, ever)
# (too, expensive)
# (cope, can)
# (boom, Hm)
# (scrape, Umm)
# (which, leads)
# (to, you)
# (the, case)
# (fold, fold)
# (Grail, Ha)
# (this, is)
# (Oh, thank)
# (Hiyya, Ha)
# (Ni, That)
# (his, headoff)
# (What, are)
# (Bloody, peasant)
# (very, much)
# (of, the)
# (happy, occasion)
# (pestilence, upon)
# (a, treat)
# (not, count)
# (Run, away)
# (Stop, it)
# (thou, shalt)
# (hee, heh)
# (in, Until)
# (My, name)
# (see, you)
# (Arthur, You)
# (Arthur, son)
# (just, to)
# (those, whom)
# (Right, Right)
# (needs, to)
# (our, society)
# (in, Camelot)
# (your, mother)
# (no, Sir)
# (chord, What)
# (are, not)
# (Is, there)
# (you, are)
# (a, shrubbery)
# (You, saw)
# (not, hear)
# (changed, into)
# (Iesu, domine)
# (biscuits, but)
# (her, into)
# (at, the)
# (freedom, Oh)
# (Is, there)
# (martin, or)
# (your, father)
# (the, most)
# (on, Oh)
# (For, since)
# (up, No)
# (Back, Riiight)
# (war, we)
# (they, could)
# (your, purpose)
# (of, you)
# (be, men)
# (Three, questions)
# (time, try)
# (No, more)
# (the, tragic)
# (beautiful, She)
# (of, spirit)
# (Quoi, Un)
# (blessing, from)
# (Sir, Launcelot)
# (there, There)
# (coconuts, We)
# (Nay, Come)
# (Sir, Robin)
# (The, Holy)
# (Who, Say)
# (Gorge, of)
# (but, a)
# (Have, at)
# (a, knight)
# (had, to)
# (Steady, And)
# (of, distress)
# (bloody, hell)
# (Brother, Maynard)
# (open, this)
# (that, case)
# (it, how)
# (Firstly, you)
# (saw, saw)
# (have, his)
# (a, walk)
# (from, witches)
# (me, to)
# (of, Camelot)
# (What, is)
# (not, quite)
# (of, the)
# (name, of)
# (not, a)
# (on, about)
# (coming, to)
# (Oh, yeah)
# (Hoo, singing)
# (you, speak)
# (Hic, And)
# (of, Ni)
# (What, Nothing)
# (after, you)
# (is, much)
# (beyond, these)
# (At, last)
# (Ni, can)
# (us, the)
# (mean, Well)
# (Robin, My)
# (end, God)
# (Come, on)
# (and, join)
# (Round, Table)
# (a, hundred)
# (that, you)
# (not, to)
# (mumble, bells)
# (sure, he)
# (going, to)
# (Agh, Right)
# (Aah, Aaah)
# (here, Oh)
# (fair, and)
# (castle, to)
# (Just, Zoot)
# (You, snore)
# (you, Thank)
# (the, curtains)
# (your, dead)
# (got, a)
# (it, Who)
# (this, door)
# (to, those)
# (Ni, and)
# (boom, Eh)
# (nasty, ways)
# (Look, you)
# (king, a)
# (bed, for)
# (yes, of)
# (to, witness)
# (and, orangutans)
# (clang, Huyah)
# (You, not)
# (help, would)
# (got, one)
# (aunties, you)
# (Launcelot, of)
# (what, coming)
# (that, an)
# (Launcelot, got)
# (in, Cornwall)
# (creak, whispering)
# (word, can)
# (quests, we)
# (of, peril)
# (the, approaching)
# (be, praised)
# (its, wings)
# (afraid, not)
# (the, horrendous)
# (Winter, Oh)
# (He, going)
# (Ha, etc)
# (no, No)
# (you, Stop)
# (So, built)
# (We, do)
# (fell, out)
# (allowed, to)
# (all, Well)
# (you, shall)
# (send, help)
# (come, to)
# (the, frozen)
# (for, some)
# (of, valor)
# (What, is)
# (You, know)
# (leg, kick)
# (do, tell)
# (do, you)
# (Oh, remember)
# (Shh, Shh)
# (Look, can)
# (sire, Then)
# (turned, about)
# (mumble, mumble)
# (shall, have)
# (Whoa, there)
# (you, hang)
# (agree, to)
# (spirit, may)
# (film, Together)
# (heh, Stop)
# (to, Camelot)
# (wounded, No)
# (force, You)
# (Lord, Well)
# (Hic, Oh)
# (to, his)
# (a, swamp)
# (Olfin, Bedwere)
# (of, you)
# (is, a)
# (hear, a)
# (her, Ah)
# (of, the)
# (witch, witch)
# (looney, The)
# (Arthur, became)
# (is, Heh)
# (table, We)
# (underwear, We)
# (dresser, So)
# (Oh, quick)
# (hundred, and)
# (Am, right)
# (a, very)
# (Beast, of)
# (Apples, Uh)
# (outrageous, accent)
# (head, smashed)
# (and, his)
# (and, get)
# (shrubbery, You)
# (the, tale)
# (singing, stops)
# (Come, on)
# (quest, for)
# (alight, to)
# (Bridge, of)
# (Please, Hold)
# (awhile, Midget)
# (the, thing)
# (Knights, bid)
# (very, very)
# (Agh, Do)
# (do, think)
# (Auuuuuuuugh, Stop)
# (everyone, He)
# (rode, north)
# (It, sank)
# (all, right)
# (then, twong)
# (would, bother)
# (this, one)
# (just, keep)
# (Ni, Ni)
# (here, beside)
# (Is, that)
# (we, go)
# (the, Holy)
# (that, Will)
# (Then, when)
# (more, or)
# (and, boil)
# (into, Autumn)
# (of, course)
# (is, Sir)
# (do, know)
# (of, stone)
# (coconut, It)
# (the, shrubbery)
# (Three, angels)
# (We, burn)
# (keep, me)
# (is, it)
# (in, the)
# (What, also)
# (and, Uh)
# (Aaauggh, Do)
# (valiant, knight)
# (we, shall)
# (what, is)
# (he, wants)
# (going, to)
# (nor, either)
# (has, entered)
# (from, a)
# (Oh, it)
# (that, uh)
# (get, but)
# (but, built)
# (be, mashed)
# (but, eight)
# (beyond, the)
# (forced, to)
# (not, afraid)
# (bottom, biters)
# (chest, This)
# (this, time)
# (fled, No)
# (necessary, We)
# (the, Grail)
# (Tim, Greetings)
# (that, We)
# (you, welcome)
# (your, name)
# (We, want)
# (Look, What)
# (thank, Thee)
# (Robin, rode)
# (grail, That)
# (Thank, you)
# (only, slightly)
# (Camelot, It)
# (Hee, ha)
# (my, liege)
# (when, he)
# (dead, Yes)
# (True, Uhh)
# (our, hospitality)
# (Amen, Right)
# (their, separate)
# (land, in)
# (he, is)
# (the, van)
# (dead, sir)
# (clop, clop)
# (mumble, mumble)
# (are, under)
# (boom, boom)
# (me, Could)
# (birds, were)
# (Three, questions)
# (anarcho, syndicalist)
# (quite, so)
# (Sir, Not)
# (Look, my)
# (to, the)
# (then, French)
# (music, stops)
# (Bravely, bold)
# (ha, ha)
# (Shh, Shh)
# (Ni, Therefore)
# (clear, Hic)
# (under, considerable)
# (Castle, of)
# (an, offensive)
# (Blue, No)
# (we, tell)
# (the, oral)
# (silly, person)
# (snows, of)
# (up, Oh)
# (to, be)
# (a, the)
# (chanting, Pie)
# (Well, this)
# (No, no)
# (beat, a)
# (witch, chanting)
# (Camelot, But)
# (for, your)
# (do, suppose)
# (for, no)
# (dance, when)
# (he, leave)
# (feel, much)
# (weather, The)
# (that, Rather)
# (a, horse)
# (your, king)
# (Bedevere, was)
# (about, who)
# (right, Please)
# (carp, and)
# (it, say)
# (my, pimples)
# (In, the)
# (chord, Not)
# (go, too)
# (a, task)
# (We, do)
# (you, shall)
# (and, have)
# (very, much)
# (understand, my)
# (enchanter, By)
# (other, people)
# (No, no)
# (nasty, big)
# (Ni, Ni)
# (Grail, Look)
# (Arthur, and)
# (dead, clang)
# (of, wood)
# (the, bride)
# (squeak, creak)
# (farcical, aquatic)
# (bladders, may)
# (to, um)
# (getting, married)
# (There, are)
# (the, same)
# (this, one)
# (donkey, bottom)
# (ptoo, Ha)
# (never, pass)
# (Round, Table)
# (this, idiom)
# (command, you)
# (clang, Bring)
# (clue, and)
# (Come, on)
# (to, eat)
# (Oh, shut)
# (Launcelot, sir)
# (at, a)
# (to, this)
# (what, are)
# (Knights, Who)
# (Holy, Grail)
# (are, non)
# (Bridge, of)
# (Brave, Sir)
# (Ni, Ohh)
# (Then, when)
# (must, spank)
# (floats, in)
# (And, his)
# (it, say)
# (My, God)
# (Oh, dear)
# (Oh, Ahh)
# (swamp, But)
# (fallen, to)
# (pond, Throw)
# (Zoot, She)
# (um, mean)
# (hello, Quick)
# (my, nose)
# (successful, conclusion)
# (And, not)
# (the, room)
# (and, argue)
# (Or, to)
# (heroic, rescue)
# (your, humble)
# (very, real)
# (to, me)
# (Just, a)
# (seemed, a)
# (escape, Look)
# (domine, donaeis)
# (me, Sir)
# (Yes, but)
# (not, Sir)
# (Tale, of)
# (We, have)
# (said, it)
# (made, of)
# (killed, the)
# (will, beat)
# (special, bi)
# (etc, Aaaaaah)
# (and, uh)
# (have, to)
# (Come, on)
# (Where, does)
# (in, medieval)
# (shut, up)
# (a, question)
# (Arthur, music)
# (but, the)
# (him, handle)
# (maintain, air)
# (in, the)
# (burn, her)
# (come, with)
# (the, Princess)
# (one, day)
# (saying, First)
# (Five, is)
# (Ni, Ni)
# (up, Um)
# (They, the)
# (this, scene)
# (just, get)
# (last, resting)
# (the, Holy)
# (the, north)
# (but, must)
# (No, Yes)
# (just, remembered)
# (spank, me)
# (here, and)
# (Picture, for)
# (that, somewhere)
# (say, Dennis)
# (Nothing, is)
# (of, the)
# (there, you)
# (Well, did)
# (Run, away)
# (jump, to)
# (a, lady)
# (scott, Hm)
# (is, that)
# (about, its)
# (Thou, hast)
# (dramatic, chord)
# (court, at)
# (a, lot)
# (to, protect)
# (another, shrubbery)
# (clap, Well)
# (Ha, ha)
# (Grail, were)
# (to, the)
# (heh, chanting)
# (Camelot, It)
# (the, other)
# (your, silly)
# (set, eyes)
# (they, listen)
# (what, it)
# (Black, Beast)
# (Bedevere, Knight)
# (tale, The)
# (requiem, bonk)
# (Ni, Ni)
# (Lead, duck)
# (the, bravest)
# (your, general)
# (Knights, Who)
# (of, a)
# (Bon, magne)
# (and, breakfast)
# (Oh, great)
# (and, my)
# (it, here)
# (valleys, of)
# (does, leave)
# (only, because)
# (Who, are)
# (us, ride)
# (In, war)
# (good, Sir)
# (Knight, of)
# (witch, Here)
# (nose, at)
# (Nador, they)
# (father, who)
# (it, Stop)
# (you, going)
# (routines, and)
# (of, the)
# (Do, say)
# (you, that)
# (room, Yes)
# (No, no)
# (the, bosom)
# (fifty, pounds)
# (line, Well)
# (we, can)
# (of, pussy)
# (word, again)
# (me, covered)
# (a, fortune)
# (is, eet)
# (knock, it)
# (Hurry, Sir)
# (father, who)
# (guard, him)
# (liege, Then)
# (a, mile)
# (Death, which)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# (er, the)
# (nearer, the)
# (was, an)
# (false, one)
# (You, do)
# (All, right)
# (most, foul)
# (at, you)
# (If, you)
# (was, a)
# (considerable, economic)
# (strength, come)
# (seek, this)
# (giggle, giggle)
# (get, the)
# (nothing, nothing)
# (Burn, Who)
# (one, Oh)
# (of, wood)
# (Please, We)
# (test, What)
# (that, castle)
# (the, dark)
# (if, you)
# (The, Castle)
# (wood, Good)
# (That, is)
# (not, open)
# (Oh, had)
# (Oh, do)
# (cough, Nu)
# (illustrious, names)
# (this, period)
# (clop, Wait)
# (just, and)
# (Arthur, music)
# (a, minute)
# (this, lot)
# (hee, ha)
# (much, peril)
# (Beast, of)
# (may, cross)
# (this, sacred)
# (commune, We)
# (Well, that)
# (mystic, runes)
# (since, the)
# (music, stops)
# (come, Look)
# (No, problems)
# (Hill, and)
# (here, until)
# (cave, Tim)
# (me, in)
# (Victory, is)
# (is, a)
# (am, a)
# (Oh, bloody)
# (to, tell)
# (the, number)
# (shrubbery, One)
# (King, Arthur)
# (bells, Hah)
# (Christ, warned)
# (the, union)
# (it, thou)
# (which, have)
# (Now, go)
# (silly, king)
# (will, to)
# (stops, boom)
# (In, twenty)
# (witches, More)
# (Heh, heh)
# (through, this)
# (have, seen)
# (upon, this)
# (Well, that)
# (only, by)
# (Iesu, domine)
# (seems, to)
# (me, go)
# (and, packing)
# (cave, is)
# (asks, each)
# (stand, it)
# (is, You)
# (very, keen)
# (doing, it)
# (wart, cough)
# (dead, clang)
# (thud, King)
# (Aauuuuugh, at)
# (Well, we)
# (singing, Brave)
# (that, Listen)
# (Zoot, Prepare)
# (intermission, suspenseful)
# (please, come)
# (Grail, It)
# (you, know)
# (It, is)
# (so, worried)
# (your, strength)
# (boom, Ay)
# (no, no)
# (Aaaaugh, Stop)
# (Launcelot, God)
# (do, wanna)
# (make, bridges)
# (was, the)
# (to, join)
# (bottom, burned)
# (biscuits, All)
# (that, Hurry)
# (a, nasty)
# (Oh, Oh)
# (Ooh, said)
# (sponge, Sir)
# (questions, Sir)
# (music, stops)
# (music, stops)
# (but, they)
# (had, a)
# (of, Antioch)
# (of, creeper)
# (the, Britons)
# (have, a)
# (mumble, mumble)
# (dramatic, chord)
# (in, the)
# (easy, Stop)
# (But, Follow)
# (and, Aaah)
# (Princess, and)
# (Tower, you)
# (Who, goes)
# (Yeaah, Did)
# (fair, one)
# (Quiet, Quiet)
# (and, in)
# (in, Camelot)
# (the, word)
# (to, tell)
# (single, handed)
# (enter, the)
# (looking, for)
# (what, do)
# (to, rest)
# (Father, Shut)
# (Quiet, Quiet)
# (dona, eis)
# (of, the)
# (does, he)
# (stayed, up)
# (impeccable, We)
# (you, a)
# (Yup, Hm)
# (then, What)
# (Ay, up)
# (Sir, Knight)
# (one, punishment)
# (African, swallow)
# (one, That)
# (sorry, Um)
# (away, Run)
# (ha, Hold)
# (executive, power)
# (twenty, four)
# (better, not)
# (he, already)
# (can, buy)
# (Yes, They)
# (he, doing)
# (No, No)
# (bonk, Pie)
# (land, in)
# (There, he)
# (Said, Ni)
# (see, Actually)
# (this, is)
# (Did, you)
# (from, it)
# (Look, please)
# (Bring, up)
# (Ohh, Ohh)
# (dear, Is)
# (are, just)
# (you, got)
# (think, you)
# (me, like)
# (new, home)
# (cut, off)
# (twang, splash)
# (Uh, here)
# (taken, Concorde)
# (right, not)
# (He, going)
# (of, Death)
# (the, van)
# (Tell, us)
# (not, jump)
# (lambs, and)
# (Right, Oh)
# (we, French)
# (high, pitched)
# (do, worry)
# (ninepence, not)
# (and, his)
# (on, a)
# (dogma, which)
# (not, also)
# (able, We)
# (Spring, changed)
# (come, You)
# (has, fought)
# (does, it)
# (you, Thank)
# (Bravely, ran)
# (Pie, Iesu)
# (boom, boom)
# (this, cave)
# (problem, What)
# (witch, witch)
# (a, scimitar)
# (Yes, What)
# (taunt, you)
# (it, sorry)
# (and, nineteen)
# (and, make)
# (How, can)
# (we, had)
# (does, leave)
# (that, what)
# (brave, Concorde)
# (cost, fifty)
# (foot, Dis)
# (No, Sir)
# (just, um)
# (to, relax)
# (out, your)
# (Why, He)
# (Arthur, having)
# (Oh, but)
# (with, you)
# (gave, Spring)
# (the, Holy)
# (time, How)
# (here, and)
# (Oh, see)
# (your, dead)
# (an, unladen)
# (Aaaaugh, Aaaaugh)
# (She, is)
# (the, dorsal)
# (Here, is)
# (killed, who)
# (What, is)
# (anything, else)
# (Oooh, Exactly)
# (Oh, Oh)
# (clop, clop)
# (All, right)
# (on, second)
# (scribble, fold)
# (guarded, by)
# (Ni, Agh)
# (That, it)
# (get, lad)
# (hospitality, Well)
# (clap, clap)
# (and, No)
# (mate, Oh)
# (Ni, Ni)
# (an, enchanter)
# (for, that)
# (ferocity, of)
# (Oh, King)
# (danger, reared)
# (The, wise)
# (to, chastity)
# (rescue, in)
# (dona, eis)
# (a, naughty)
# (Uther, Pendragon)
# (in, the)
# (dine, well)
# (bois, Quoi)
# (be, killed)
# (woosh, Oooh)
# (the, best)
# (he, is)
# (was, much)
# (eat, ham)
# (armor, Let)
# (Charge, mayhem)
# (you, could)
# (niggets, and)
# (kills, Frank)
# (hear, that)
# (Where, are)
# (you, marrying)
# (the, violence)
# (medical, training)
# (was, was)
# (this, note)
# (shaped, This)
# (will, say)
# (many, did)
# (Holy, Hand)
# (shalt, count)
# (Arthur, from)
# (out, your)
# (our, guest)
# (Ni, Peng)
# (and, anchovies)
# (answer, the)
# (praised, King)
# (you, the)
# (name, Sir)
# (have, a)
# (indefatigable, Between)
# (to, No)
# (bugger, folk)
# (nick, of)
# (speak, with)
# (European, swallow)
# (and, able)
# (And, his)
# (Robin, never)
# (the, door)
# (pounds, each)
# (a, mistake)
# (Perhaps, he)
# (Look, squeak)
# (You, a)
# (Say, Ni)
# (who, We)
# (a, busy)
# (anyway, On)
# (squeak, boom)
# (who, are)
# (we, could)
# (on, Come)
# (Oh, Oh)
# (in, the)
# (one, pound)
# (Just, ignore)
# (Stop, Who)
# (Lancelot, who)
# (do, brush)
# (one, Well)
# (mistake, Like)
# (cereals, and)
# (science, am)
# (Robin, set)
# (the, Grail)
# (wood, alive)
# (a, daring)
# (test, Knights)
# (Brother, Maynard)
# (the, animator)
# (as, King)
# (dramatic, chord)
# (are, you)
# (leap, out)
# (Bravest, of)
# (He, going)
# (does, leave)
# (swamp, but)
# (its, lair)
# (banana, shaped)
# (it, Yes)
# (and, his)
# (order, to)
# (ha, ha)
# (Not, to)
# (is, your)
# (Get, on)
# (built, a)
# (to, come)
# (the, old)
# (stops, blessing)
# (why, not)
# (a, good)
# (killed, eight)
# (brave, Sir)
# (Oh, hello)
# (seek, the)
# (is, Well)
# (was, not)
# (Launcelot, and)
# (Jesus, Christ)
# (apart, No)
# (dub, you)
# (This, is)
# (of, Eternal)
# (supreme, executive)
# (If, he)
# (a, blanket)
# (is, how)
# (dramatic, chord)
# (If, she)
# (you, knew)
# (You, tit)
# (Midget, Crapper)
# (carve, aaggggh)
# (lads, Heh)
# (winter, covered)
# (room, even)
# (clap, And)
# (No, no)
# (Hello, Hello)
# (Now, stand)
# (Aagh, Oh)
# (surprise, but)
# (Thursday, Right)
# (Camelot, He)
# (Stop, What)
# (come, to)
# (am, Zoot)
# (started, here)
# (it, and)
# (Skip, a)
# (ha, ha)
# (no, No)
# (spanking, the)
# (snap, Oh)
# (this, grail)
# (Three, questions)
# (was, better)
# (wield, supreme)
# (you, come)
# (But, many)
# (Get, the)
# (attend, to)
# (that, out)
# (another, frontal)
# (and, make)
# (the, Lord)
# (cross, this)
# (we, did)
# (e, does)
# (no, man)
# (will, give)
# (Our, quest)
# (Keep, me)
# (Ha, haw)
# (in, your)
# (find, the)
# (the, Holy)
# (minute, Supposing)
# (away, Go)
# (fifty, men)
# (What, is)
# (is, mine)
# (like, those)
# (has, been)
# (bit, bit)
# (you, come)
# (Aaaaugh, You)
# (boom, make)
# (Then, you)
# (use, a)
# (If, only)
# (The, beds)
# (sure, the)
# (Ni, Ni)
# (no, please)
# (bringing, class)
# (your, heads)
# (think, think)
# (on, Back)
# (search, of)
# (to, wield)
# (of, the)
# (It, a)
# (on, Just)
# (Knights, of)
# (What, knight)
# (your, dead)
# (He, says)
# (throughout, the)
# (of, the)
# (you, were)
# (rewr, your)
# (wounding, of)
# (bad, naughty)
# (Shh, Shh)
# (direction, sons)
# (yelling, Hold)
# (away, Run)
# (King, Arthur)
# (We, are)
# (a, wonderful)
# (were, You)
# (said, was)
# (doing, in)
# (What, language)
# (Holy, Grail)
# (him, Until)
# (You, just)
# (chanting, Pie)
# (Oh, there)
# (No, am)
# (that, Oooh)
# (One, thing)
# (can, get)
# (more, time)
# (you, kick)
# (No, Never)
# (many, men)
# (the, room)
# (feel, fine)
# (But, there)
# (of, the)
# (a, question)
# (anyone, No)
# (Yes, Let)
# (Knight, afraid)
# (Yes, Zoot)
# (sex, The)
# (of, the)
# (silly, thing)
# (Grail, Oh)
# (bum, He)
# (does, Launcelot)
# (Stop, that)
# (is, your)
# (harmless, little)
# (a, certain)
# (Well, taken)
# (All, right)
# (and, take)
# (Over, here)
# (are, you)
# (uh, sort)
# (What, do)
# (Holy, Grail)
# (on, Bors)
# (castle, Oh)
# (command, you)
# (pissing, off)
# (not, next)
# (off, in)
# (would, be)
# (that, off)
# (music, a)
# (her, down)
# (thought, your)
# (you, Uh)
# (Yes, Let)
# (Knight, always)
# (us, what)
# (My, liege)
# (old, man)
# (take, out)
# (So, logically)
# (right, not)
# (a, coconut)
# (on, then)
# (is, a)
# (sure, he)
# (going, to)
# (Arthur, King)
# (Right, Remove)
# (It, not)
# (He, who)
# (Yeah, a)
# (And, want)
# (of, telling)
# (We, opera)
# (have, a)
# (for, the)
# (exciting, music)
# (yes, Yes)
# (dead, clang)
# (nobody, really)
# (to, come)
# (there, lies)
# (would, cross)
# (lapin, lapin)
# (Grail, Oh)
# (number, be)
# (can, you)
# (you, Come)
# (stop, bitching)
# (Clear, off)
# (my, duty)
# (Sir, Knight)
# (a, shrubbery)
# (Well, do)
# (autonomous, collective)
# (one, of)
# (Three, questions)
# (any, more)
# (Loimbard, Go)
# (we, shall)
# (up, from)
# (All, right)
# (in, the)
# (Bors, Chop)
# (Arthur, knights)
# (let, kill)
# (That, it)
# (stand, aside)
# (afraid, What)
# (last, leg)
# (were, soon)
# (clop, clop)
# (heh, heeh)
# (Uh, they)
# (he, has)
# (a, glass)
# (And, again)
# (two, young)
# (no, man)
# (Antioch, Tis)
# (times, we)
# (That, sank)
# (leave, and)
# (Maynard, carries)
# (You, got)
# (Pure, and)
# (soon, He)
# (etc, Run)
# (chops, the)
# (us, easily)
# (Oh, Great)
# (Churches, Churches)
# (Hello, Hello)
# (note, you)
# (Ere, He)
# (Well, does)
# (sacred, words)
# (Shh, Knights)
# (We, dine)
# (So, he)
# (is, Zoot)
# (Arthur, for)
# (Say, Ecky)
# (times, every)
# (Right, Keep)
# (in, medieval)
# (obviously, mean)
# (shivering, Winter)
# ...
# (got, one)
# (All, that)
# (is, hidden)
# (Not, like)
# (the, Shrubber)
# (you, listen)
# (it, very)
# (climes, in)
# (icy, hand)
# (you, mean)
# (thud, Ah)
# (it, in)
# (and, bit)
# (a, witch)
# (are, ways)
# (Heh, heh)
# (can, understand)
# (is, that)
# (go, Who)
# (your, quest)
# (would, hear)
# (You, are)
# (haste, Who)
# (Are, you)
# (collective, You)
# (not, He)
# (of, the)
# (this, scene)
# (you, will)
# (think, have)
# (whinny, whinny)
# (warmer, climes)
# (is, this)
# (to, help)
# (very, living)
# (the, Grail)
# (brought, you)
# (And, if)
# (adversary, Tis)
# (life, must)
# (No, Not)
# (liege, trumpets)
# (at, Camelot)
# (Then, dub)
# (your, escape)
# (name, are)
# (Knights, of)
# (a, window)
# (you, so)
# (soft, and)
# (God, name)
# (me, that)
# (noise, you)
# (man, So)
# (coconut, back)
# (music, Ooh)
# (a, silly)
# (No, no)
# (who, answers)
# (at, this)
# (God, dramatic)
# (Yeah, We)
# (an, anarcho)
# (is, this)
# (at, once)
# (really, uh)
# (clap, clap)
# (mumble, mumble)
# (sure, e)
# (And, me)
# (de, bois)
# (The, oral)
# (through, the)
# (up, to)
# (very, good)
# (bit, longer)
# (make, sure)
# (to, think)
# (is, one)
# (help, you)
# (the, Lord)
# (of, the)
# (Hiyah, Aah)
# (out, your)
# (What, are)
# (Oh, yes)
# (What, he)
# (carried, by)
# (was, no)
# (Well, at)
# (all, afraid)
# (clap, Oh)
# (it, quite)
# (Eee, And)
# (a, mandate)
# (all, England)
# (the, least)
# (Which, one)
# (lapin, de)
# (say, is)
# (old, Well)
# (Hello, Hello)
# (her, Burn)
# (to, know)
# (Holy, Grail)
# (of, Ni)
# (Dappy, Today)
# (whom, Which)
# (it, Amen)
# (quack, We)
# (really, just)
# (clop, clop)
# (Message, for)
# (in, this)
# (but, dangerous)
# (tell, us)
# (Grail, in)
# (Of, course)
# (is, Come)
# (back, Hic)
# (been, more)
# (Go, away)
# (Really, Honestly)
# (to, find)
# (Camelot, in)
# (Sir, Launcelot)
# (How, dare)
# (Churches, Lead)
# (him, but)
# (you, know)
# (Heh, hee)
# (her, How)
# (eh, That)
# (witch, We)
# (clop, Who)
# (of, winter)
# (blow, my)
# (What, swallow)
# (her, Burn)
# (Castle, At)
# (you, in)
# (keepers, of)
# (yes, you)
# (uh, by)
# (witch, Burn)
# (squeak, squeak)
# (the, masses)
# (swallows, are)
# (hat, but)
# (a, herring)
# (best, leave)
# (that, You)
# (No, that)
# (word, if)
# (the, Bridge)
# (Patsy, None)
# (dorsal, guiding)
# (bottom, sons)
# (dramatic, chord)
# (say, the)
# (leave, them)
# (arm, off)
# (away, Just)
# (Oh, but)
# (four, Beyond)
# (dona, eis)
# (sons, of)
# (that, Stop)
# (witch, Well)
# (not, fooling)
# (in, ponds)
# (learning, amazes)
# (to, talk)
# (have, been)
# (my, name)
# (is, your)
# (drilllll, sawwwww)
# (Wayy, twang)
# (thank, Thee)
# (tiny, bits)
# (and, carp)
# (think, not)
# (Oh, not)
# (Say, Ni)
# (Oh, do)
# (we, looking)
# (interested, It)
# (Arimathea, Course)
# (pure, of)
# (Yes, we)
# (Who, lives)
# (faced, bugger)
# (mumble, boom)
# (this, thy)
# (but, now)
# (all, this)
# (clop, Now)
# (Uh, Oh)
# (Camelot, Are)
# (my, friend)
# (you, sir)
# (Stop, What)
# (and, make)
# (chord, what)
# (cadeau, Oui)
# (you, but)
# (Oh, wo)
# (of, the)
# (died, while)
# (who, seek)
# (going, to)
# (Lady, of)
# (the, nose)
# (as, a)
# (do, vote)
# (two, excepting)
# (castanets, out)
# (you, music)
# (Assyria, do)
# (on, me)
# (out, and)
# (Table, Who)
# (to, Did)
# (because, some)
# (just, to)
# (marry, to)
# (quite, dead)
# (Thank, you)
# (old, dad)
# (nibble, your)
# (four, What)
# (Arthur, The)
# (singing, He)
# (requiem, Pie)
# (singing, He)
# (let, go)
# (For, since)
# (unhealthy, bet)
# (the, boys)
# (your, dead)
# (saw, saw)
# (his, only)
# (Hello, He)
# (What, a)
# (longer, the)
# (We, shall)
# (music, And)
# (that, France)
# (you, ca)
# (of, the)
# (lie, strewn)
# (Augh, Ohh)
# (tell, you)
# (he, think)
# (the, swamp)
# (the, most)
# (she, is)
# (You, only)
# (think, so)
# (Eternal, Peril)
# (you, good)
# (to, be)
# (to, his)
# (was, saved)
# (Let, me)
# (fortune, Well)
# (kick, Eh)
# (Heh, heh)
# (that, no)
# (bless, this)
# (let, not)
# (daughter, to)
# (thud, thud)
# (about, Did)
# (late, dramatic)
# (Oh, come)
# (carried, it)
# (king, thought)
# (forest, of)
# (quite, dead)
# (Old, woman)
# (Yes, have)
# (a, strange)
# (you, gay)
# (a, drink)
# (upon, the)
# (saw, saw)
# (splat, In)
# (rabbit, It)
# (Did, you)
# (limbs, all)
# (No, it)
# (executive, officer)
# (Let, us)
# (averting, my)
# (One, that)
# (and, get)
# (How, you)
# (shimmering, samite)
# (at, you)
# (first, time)
# (afraid, when)
# (He, going)
# (was, looking)
# (It, is)
# (Who, does)
# (Round, Table)
# (protect, us)
# (seen, it)
# (leave, the)
# (the, Castle)
# (Back, with)
# (handed, No)
# (haw, heh)
# (for, the)
# (right, sonny)
# (shalt, thou)
# (hall, tap)
# (it, Hold)
# (What, There)
# (court, at)
# (Oh, king)
# (know, the)
# (another, shrubbery)
# (unclog, my)
# (could, stay)
# (a, daughter)
# (No, No)
# (you, Thank)
# (boom, howl)
# (one, They)
# (me, And)
# (off, Go)
# (of, Ewing)
# (where, does)
# (words, of)
# (is, there)
# (Yapping, on)
# (with, a)
# (the, mightiest)
# (Packing, it)
# (lad, But)
# (Arthur, and)
# (answer, the)
# (heh, Old)
# (lives, in)
# (on, all)
# (up, a)
# (held, aloft)
# (at, the)
# (not, tell)
# (unsingable, We)
# (you, What)
# (sir, Very)
# (Get, that)
# (What, held)
# (Right, clop)
# (Launcelot, One)
# (Saxons, sovereign)
# (she, weighs)
# (swamp, So)
# (nineteen, and)
# (Hooray, police)
# (auntie, yelling)
# (Lord, spake)
# (its, ugly)
# (Who, Say)
# (sank, into)
# (used, to)
# (was, in)
# (much, rejoicing)
# (that, with)
# (were, to)
# (Hold, it)
# (Just, pull)
# (Oh, that)
# (on, Well)
# (idea, smack)
# (My, liege)
# (kneecaps, split)
# (To, seek)
# (longer, have)
# (naughty, evil)
# (baaaa, Jesus)
# (have, a)
# (We, are)
# (assist, us)
# (have, to)
# (through, What)
# (it, have)
# (a, half)
# (sure, e)
# (You, are)
# (Is, it)
# (Aauuugh, no)
# (he, a)
# (it, Yes)
# (breath, Well)
# (carved, in)
# (do, want)
# (is, there)
# (Ni, demand)
# (got, a)
# (the, ones)
# (one, live)
# (eis, requiem)
# (shall, take)
# (giggle, giggle)
# (Pin, Then)
# (think, you)
# (mean, if)
# (in, Thy)
# (task, to)
# (Oh, stop)
# (sure, that)
# (this, town)
# (find, a)
# (quack, quack)
# (were, to)
# (crossed, But)
# (dead, What)
# (that, in)
# (Oh, it)
# (no, sweet)
# (Yes, You)
# (Britons, My)
# (nine, today)
# (is, here)
# (He, just)
# (Come, on)
# (bit, scared)
# (setting, alight)
# (make, sure)
# (seek, the)
# (if, we)
# (ruffians, can)
# (know, much)
# (Yeaaah, Yeaah)
# (think, all)
# (tell, Shut)
# (nostrils, raped)
# (for, a)
# (words, the)
# (King, of)
# (up, singing)
# (clop, music)
# (lucky, You)
# (you, Oh)
# (boom, mumble)
# (well, here)
# (to, show)
# (is, the)
# (whom, God)
# (we, best)
# (ni, at)
# (We, have)
# (bloody, swamp)
# (brave, and)
# (the, brave)
# (dying, he)
# (that, Arthur)
# (pound, In)
# (Well, you)
# (And, take)
# (trumpets, The)
# (not, given)
# (favorite, color)
# (stops, One)
# (Uh, You)
# (attack, exciting)
# (could, say)
# (watery, tart)
# (and, Monsieur)
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# (the, throat)
# (not, stop)
# (Come, on)
# (it, by)
# (am, a)
# (away, And)
# (violence, inherent)
# (shrubberies, are)
# (cut, down)
# (brained, wipers)
# (Come, along)
# (Yes, Yeah)
# (fought, the)
# (worried, when)
# (Aaaugh, Aaaugh)
# (you, Camelot)
# (you, must)
# (you, do)
# (go, bringing)
# (it, you)
# (this, room)
# (boom, boom)
# (we, lose)
# (So, be)
# (at, the)
# (the, people)
# (of, the)
# (Charge, Charge)
# (sir, Yeah)
# (that, all)
# (found, the)
# (it, is)
# (now, remain)
# (uh, anything)
# (Launcelot, Hurry)
# (lived, Bones)
# (Sir, Robin)
# (could, talk)
# (all, right)
# (duck, she)
# (a, Well)
# (of, Death)
# (put, me)
# (got, two)
# (is, the)
# (was, not)
# (Just, me)
# (place, it)
# (Do, you)
# (Run, along)
# (kill, him)
# (your, sword)
# (Uh, but)
# (that, singing)
# (the, Court)
# (fine, Come)
# (vain, Uh)
# (dead, Here)
# (lies, a)
# (you, tiny)
# (ha, ha)
# (saw, saw)
# (like, an)
# (bird, could)
# (leave, the)
# (Run, awaaaaay)
# (we, shall)
# (clop, rewr)
# (we, see)
# (Defeat, at)
# (for, it)
# (You, silly)
# (the, Holy)
# (down, the)
# (water, clank)
# (of, executive)
# (clop, You)
# (room, No)
# (language, is)
# (Death, must)
# (eisrequiem, How)
# (them, Yes)
# (kind, And)
# (then, of)
# (You, were)
# (He, is)
# (us, Tell)
# (it, is)
# (Hmm, mumble)
# (what, it)
# (squeak, squeak)
# (have, got)
# (Iesu, domine)
# (and, all)
# (You, got)
# (cough, clang)
# (you, silly)
# (liar, Come)
# (at, will)
# (as, you)
# (It, only)
# (you, must)
# (something, Oh)
# (and, Arthur)
# (Once, the)
# (ni, to)
# (a, witch)
# (armor, was)
# (round, Thursday)
# (It, unhealthy)
# (Please, can)
# (does, leave)
# (bother, to)
# (which, the)
# (sword, out)
# (for, the)
# (number, of)
# (cut, the)
# (Ah, What)
# (can, you)
# (witch, witch)
# (No, No)
# (Hello, Zoot)
# (Thppt, Thppt)
# (wicked, wicked)
# (a, witch)
# (knights, of)
# (not, you)
# (So, We)
# (out, bravely)
# (Aaaaugh, And)
# (twang, chanting)
# (like, this)
# (Not, the)
# (clang, Bring)
# (able, Quite)
# (No, no)
# (syndicalism, is)
# (there, and)
# (jam, and)
# (from, uh)
# (tell, Shut)
# (is, your)
# (the, aptly)
# (ugly, head)
# (In, God)
# (Ni, you)
# (want, any)
# (kings, said)
# (you, from)
# (it, Hold)
# (God, be)
# (Augh, we)
# (a, simple)
# (not, old)
# (the, time)
# (That, burned)
# (anchovies, and)
# (Of, course)
# (it, Run)
# (name, of)
# (for, the)
# (in, a)
# (you, very)
# (answer, me)
# (clllank, What)
# (him, feel)
# (dead, and)
# (it, is)
# (him, in)
# (Oh, Hello)
# (suggesting, coconuts)
# (No, and)
# (fly, south)
# (Uh, not)
# (am, a)
# (Camelot, We)
# (is, Yeah)
# (or, the)
# (already, got)
# (a, hamster)
# (foul, temptress)
# (You, just)
# (in, surprise)
# (vouchsafed, to)
# (afoot, Anarcho)
# (Camaaaaaargue, Where)
# (witch, witch)
# (nice, a)
# (singing, He)
# (emperor, just)
# (the, land)
# (Robin, you)
# (Oh, all)
# (Lord, bless)
# (bottoms, If)
# (Look, you)
# (the, Britons)
# (did, say)
# (clop, clop)
# (la, vache)
# (will, never)
# (the, room)
# (sure, that)
# (you, do)
# (those, guards)
# (a, coconut)
# (since, the)
# (must, answer)
# (Grail, Brave)
# (velocity, a)
# (hang, around)
# (must, cross)
# (welcome, to)
# (Say, Ni)
# (their, search)
# (rich, She)
# (No, feel)
# (together, So)
# (music, The)
# (brave, Sir)
# (seek, the)
# (Quoi, Fetchez)
# (master, that)
# (nearly, fought)
# (the, sacred)
# (the, husk)
# (you, see)
# (domine, dona)
# (Oh, no)
# (streak, a)
# (European, swallow)
# (sad, times)
# (us, no)
# (that, Arthur)
# (velocity, of)
# (away, Just)
# (Holy, Grail)
# (in, our)
# (Heh, hee)
# (buy, a)
# (ceremony, Be)
# (five, Three)
# (you, Now)
# (Oh, let)
# (the, real)
# (tear, them)
# (saw, saw)
# (Morning, Oooh)
# (with, just)
# (if, the)
# (And, feel)
# (somebody, give)
# (as, her)
# (one, Ninepence)
# (not, biscuits)
# (He, come)
# (no, no)
# (away, Shut)
# (Christ, Christ)
# (Grail, have)
# (are, Yeah)
# (must, seem)
# (teeth, What)
# (duck, you)
# (thing, Oh)
# (Aaah, hiyaah)
# (Dramatically, singing)
# (Iesu, domine)
# (into, one)
# (on, on)
# (Ahh, Ahh)
# (worst, Very)
# (Shh, We)
# (There, nothing)
# (uh, you)
# (yes, Saint)
# (to, do)
# (Oh, Oh)
# (second, thought)
# (it, Hold)
# (one, for)
# (Who, are)
# (carry, on)
# (mooooooo, Jesus)
# (time, mac)
# (mashed, into)
# (you, could)
# (ha, ha)
# (Camelot, What)
# (brave, Sir)
# (a, two)
# (was, swamp)
# (is, throwing)
# (And, the)
# (That, my)
# (When, started)
# (say, shrubberies)
# (Ohh, ha)
# (better, than)
# (of, the)
# (the, quest)
# (clop, clop)
# (thy, hand)
# (say, it)
# (Oh, yeah)
# (name, My)
# (autocracy, in)
# (going, to)
# (can, leap)
# (see, Running)
# (Oooohoohohooo, No)
# (wise, Sir)
# (must, give)
# (saying, the)
# (Book, of)
# (nose, in)
# (do, need)
# (Sir, Galahad)
# (You, must)
# (come, with)
# (to, your)
# (the, Court)
# (No, not)
# (of, Aaauugh)
# (simple, Uh)
# (aaaaaah, Oooh)
# (or, shall)
# (penalty, Do)
# (single, handed)
# (through, sir)
# (Look, that)
# (Hello, Hello)
# (questions, Three)
# (types, a)
# (see, knew)
# (are, you)
# (ca, Well)
# (we, come)
# (ha, ha)
# (Tis, one)
# (your, name)
# (seems, to)
# (so, called)
# (Ho, ho)
# (if, you)
# (could, not)
# (It, could)
# (the, room)
# (clop, clop)
# (The, cartoon)
# (the, Holy)
# (do, think)
# (of, preserving)
# (one, is)
# (beside, this)
# (witch, witch)
# (home, Yes)
# (dressed, me)
# (his, nostrils)
# (must, find)
# (me, And)
# (just, just)
# (Hallo, pause)
# (are, doctors)
# (mother, was)
# (do, singing)
# (Galahad, You)
# (the, big)
# (we, demand)
# (to, carry)
# (Sir, Bedevere)
# (making, exciting)
# (pull, it)
# (Thursday, think)
# (you, get)
# (for, the)
# (will, be)
# (said, it)
# (Oh, shut)
# (Robin, Yes)
# (Ni, Firstly)
# (Ulk, thump)
# (will, attend)
# (You, be)
# (a, find)
# (No, We)
# (Oooh, splat)
# (there, someone)
# (death, upon)
# (wood, Build)
# (is, that)
# (hear, Please)
# (call, your)
# (swallow, What)
# (alive, Knights)
# (is, my)
# (you, hear)
# (marrying, Princess)
# (he, would)
# (as, a)
# (wet, himself)
# (spam, a)
# (case, shall)
# (life, not)
# (escape, for)
# (entrance, to)
# (Stand, by)
# (There, only)
# (Zoot, Just)
# (suddenly, the)
# (land, to)
# (He, killed)
# (The, dead)
# (to, tell)
# (ye, be)
# (Allo, Who)
# (wom, Neee)
# (God, with)
# (twin, sister)
# (knew, someone)
# (bravely, he)
# (swallow, flight)
# (cadeau, What)
# (stops, Aaagh)
# (convinced, that)
# (That, is)
# (clang, Bring)
# (am, Arthur)
# (this, bridge)
# (far, from)
# (Oooooooh, in)
# (miserable, they)
# (No, No)
# (k, nnnnniggets)
# (this, Aah)
# (want, any)
# (could, do)
# (the, supports)
# (clap, clap)
# (confuse, it)
# (once, Torment)
# (hand, grenade)
# (forty, three)
# (thing, you)
# (Who, leaps)
# (did, grin)
# (of, Armaments)
# (path, Ni)
# (no, nearer)
# (sod, What)
# (look, here)
# (no, more)
# (get, him)
# (singing, What)
# (there, again)
# (handle, us)
# (sing, Arthur)
# (a, plan)
# (the, forest)
# (one, Are)
# (of, two)
# (warning, you)
# (act, as)
# (on, then)
# (who, had)
# (Aaaaugh, Aaaugh)
# (just, call)
# (Castle, Anthrax)
# (worked, up)
# (fart, in)
# (the, keepers)
# (of, Mercea)
# (If, there)
# (he, had)
# (private, parts)
# (of, the)
# (has, got)
# (be, quiet)
# (all, the)
# (Holy, Grail)
# (glad, It)
# (to, kill)
# (these, questions)
# (an, unladen)
# (boing, goodem)
# (Castle, Aaagh)
# (tell, Shut)
# (Yes, we)
# (singing, To)
# (this, one)
# (is, No)
# (so, depressing)
# (passing, through)
# (government, Supreme)
# (laden, swallows)
# (while, here)
# (this, man)
# (chord, We)
# (said, the)
# (English, bed)
# (No, no)
# (eyes, gouged)
# (Thank, you)
# (filth, down)
# (the, working)
# (Thppt, What)
# (that, clear)
# (cross, the)
# (Camelot, must)
# (water, signifying)
# (the, rabbit)
# (you, do)
# (Grail, Come)
# (Old, man)
# (you, must)
# (is, a)
# (get, on)
# (of, Camelot)
# (if, he)
# (by, my)
# (Yes, brave)
# (Knight, will)
# (your, dad)
# (can, do)
# (pass, have)
# (although, think)
# (lobbest, thou)
# (that, what)
# (day, King)
# (your, lord)
# (good, do)
# (Bloody, weather)
# (what, it)
# (here, in)
# (can, help)
# (particular, sigh)
# (do, we)
# (is, Silence)
# (heeh, ooh)
# (and, influential)
# (you, Oh)
# (like, one)
# (and, Sir)
# (What, word)
# (What, Yapping)
# (Umhm, uh)
# (the, Brave)
# (bold, Sir)
# (bit, She)
# (therefore, witch)
# (vital, clue)
# (of, the)
# (there, is)
# (search, to)
# (God, be)
# (boom, Ayy)
# (away, Did)
# (English, k)
# (Oui, oui)
# (still, no)
# (great, idea)
# (shrubberies, Ni)
# (He, got)
# (and, fair)
# (Shh, Shh)
# (sacred, castle)
# (and, change)
# (find, you)
# (and, the)
# (is, your)
# (yes, Oh)
# (Stay, here)
# (Do, they)
# (Pie, Iesu)
# (ca, take)
# (witch, witch)
# (witch, witch)
# (Sir, Robin)
# (tired, and)
# (present, Oh)
# (Robin, brave)
# (is, Arthur)
# (be, a)
# (his, death)
# (good, lady)
# (of, Sir)
# (Too, late)
# (No, chance)
# (to, our)
# (thump, The)
# (can, No)
# (should, separate)
# (to, have)
# (get, a)
# (We, an)
# (inside, castle)
# (kills, thud)
# (that, an)
# (ham, and)
# (but, you)
# (Right, Silly)
# (Yes, he)
# (hee, ha)
# (Shut, up)
# (Right, do)
# (twang, whispering)
# (Caerbannog, Right)
# (rest, awhile)
# (all, between)
# (saw, saw)
# (the, room)
# (shall, do)
# (only, if)
# (life, bathing)
# (Hello, Hello)
# (actually, sir)
# (stand, aside)
# (am, and)
# (you, Oh)
# (was, just)
# (silly, knees)
# (Patsy, We)
# (No, Hang)
# (had, a)
# (you, if)
# (got, a)
# (k, nnniggets)
# (your, lord)
# (was, dictating)
# (Robin, ran)
# (breadth, of)
# (the, hills)
# (quite, simple)
# (that, they)
# (derives, from)
# (is, mine)
# (No, shrubberies)
# (just, say)
# (Bristol, and)
# (time, a)
# (Torment, me)
# (Grail, is)
# (we, all)
# (good, people)
# (uh, wait)
# (not, biscuits)
# (not, right)
# (taunting, this)
# (did, you)
# (bad, naughty)
# (zoop, boing)
# (understanding, thonk)
# (that, marry)
# (To, whoever)
# (now, averting)
# (have, seen)
# (Launcelot, had)
# (and, this)
# (None, shall)
# (clop, clop)
# (little, bunny)
# (you, go)
# (and, Ni)
# (for, it)
# (stop, that)
# (Burn, her)
# (nice, And)
# (going, to)
# (we, got)
# (got, a)
# (Splendid, Aah)
# (her, spanking)
# (a, strand)
# (seen, the)
# (dona, eisrequiem)
# (fwump, Concorde)
# (your, bum)
# (have, music)
# (questions, three)
# (Guards, Make)
# (on, Hang)
# (hear, that)
# (and, Neee)
# (even, if)
# (Sorry, You)
# (uuggggggh, Aauuggghhh)
# (you, am)
# (supposed, to)
# (We, take)
# (are, wounded)
# (sons, of)
# (is, Roger)
# (Ni, Ni)
# (He, said)
# (ca, take)
# (guiding, feathers)
# (rewr, Old)
# (north, there)
# (King, of)
# (have, died)
# (here, my)
# (quest, for)
# (brave, Sir)
# (a, guard)
# (the, Holy)
# (Please, This)
# (us, in)
# (to, conclusions)
# (not, that)
# (cave, of)
# (Doctor, Winston)
# (become, so)
# (and, the)
# (she, is)
# (him, in)
# (every, second)
# (singing, stops)
# (All, right)
# (duck, quack)
# (dona, eis)
# (mumble, mumble)
# (of, course)
# (on, the)
# (is, a)
# (Silly, little)
# (Are, you)
# (saw, saw)
# (got, it)
# (such, thing)
# (mother, There)
# (witches, burn)
# (We, must)
# (going, to)
# (eats, That)
# (the, rabbit)
# (can, explain)
# (Yes, It)
# (see, Ask)
# (nnnnniggets, Thpppppt)

# %% [markdown]
# # Word Embeddings (Word Vectors)
#
# Word embeddings (word vectors) are numeric representations of words, usually generated via dimensionality reduction on a word cooccurrence matrix for a large corpus. The vectors SpaCy uses are the [GloVe](http://nlp.stanford.edu/projects/glove/) vectors, Stanford's Global Vectors for Word Representation. These vectors can be used to calculate semantic similarity between words and documents.

# %% [markdown]
# Let's look at vectors for _Pride and Prejudice_. First, let's get the first 150 nouns:

# %%
prideNouns = [word for word in pride if word.pos_.startswith('N')][:150]

# %%
prideNouns
# Out:
# [﻿It,
#  truth,
#  man,
#  possession,
#  fortune,
#  want,
#  wife,
#  feelings,
#  views,
#  man,
#  neighbourhood,
#  truth,
#  minds,
#  families,
#  property,
#  one,
#  daughters,
#  lady,
#  one,
#  day,
#  answer,
#  wife,
#  objection,
#  invitation,
#  dear,
#  man,
#  fortune,
#  north,
#  chaise,
#  four,
#  place,
#  possession,
#  servants,
#  house,
#  end,
#  week,
#  name,
#  dear,
#  man,
#  fortune,
#  four,
#  five,
#  thousand,
#  year,
#  thing,
#  girls,
#  wife,
#  one,
#  design,
#  Design,
#  Nonsense,
#  love,
#  one,
#  occasion,
#  girls,
#  dear,
#  share,
#  beauty,
#  woman,
#  five,
#  daughters,
#  thinking,
#  beauty,
#  cases,
#  woman,
#  beauty,
#  dear,
#  neighbourhood,
#  daughters,
#  establishment,
#  one,
#  account,
#  newcomers,
#  lines,
#  consent,
#  marrying,
#  girls,
#  word,
#  thing,
#  bit,
#  others,
#  half,
#  preference,
#  none,
#  girls,
#  quickness,
#  sisters,
#  children,
#  way,
#  delight,
#  compassion,
#  nerves,
#  dear,
#  respect,
#  nerves,
#  friends,
#  consideration,
#  twenty,
#  years,
#  men,
#  four,
#  thousand,
#  year,
#  neighbourhood,
#  use,
#  twenty,
#  dear,
#  twenty,
#  mixture,
#  parts,
#  humour,
#  reserve,
#  caprice,
#  experience,
#  three,
#  twenty,
#  years,
#  wife,
#  character,
#  mind,
#  woman,
#  understanding,
#  information,
#  temper,
#  business,
#  life,
#  daughters,
#  solace,
#  news,
#  Chapter,
#  2,
#  wife,
#  evening,
#  visit,
#  knowledge,
#  manner,
#  daughter,
#  hat,
#  way,
#  mother,
#  assemblies,
#  thing,
#  two,
#  nieces,
#  woman,
#  opinion,
#  reply,
#  one,
#  daughters,
#  sake]

# %% [markdown]
# Now let's get vectors and labels for each of them:

# %%
prideNounVecs = [word.vector for word in prideNouns]
prideNounLabels = [word.string.strip() for word in prideNouns]

# %%
print (prideNounVecs[0])
# Out:
# [-1.4152594   0.45971322 -0.9178735   2.7397466   4.1198945  -2.472838
#  -0.57143956  1.5299594   4.415185    3.9129422  -0.03801548  3.6013741
#   1.3036608   0.0369436  -3.7250876  -1.0370327  -1.2157063   1.0435308
#  -0.6208026  -0.8350083   2.8902025   1.922413    0.15259613 -1.0805628
#  -1.89551    -1.2068835   0.827456   -1.1236258  -0.9814154  -0.765808
#   1.3754084   0.31375355 -2.2977557  -4.169454    3.4417782  -2.0211
#   3.7276583  -0.5868722  -3.5954812   3.6312985   3.988275    2.6913078
#  -0.08166742 -5.605893    2.847681    3.973717   -0.17512983  1.0985993
#  -1.7482393   3.2569914   2.417911   -0.82431525 -2.8261254   1.6035402
#  -3.271429    3.689102    1.7419379  -0.74784863  1.4309633   0.47724903
#  -0.60304785  1.6114899   0.08969769  2.3144832   4.94882     0.2546028
#  -0.958599   -4.245271   -1.2402717   1.1358163  -0.6716312  -0.26478443
#   1.4553194   0.75391597 -2.6361995  -0.28911164  2.161076   -4.5754786
#  -3.8752236  -1.4662546   0.15692109 -0.5268869  -3.6577156  -0.48889226
#  -1.4861012  -1.9203087  -4.287599   -1.3577743  -0.291607    1.1242882
#  -1.4603994  -1.1435308  -0.16090667  1.5304478   2.2308884  -0.25813758]

# %%
prideNounVecs[0].shape
# Out:
# (96,)

# %% [markdown]
# A single vector is 96-dimensional, so in order to plot it in 2D, it might help to reduce the dimensionality to the most meaningful dimensions. We can use Scikit-Learn to perform truncated singular value decomposition for latent semantic analysis (LSA).

# %%
lsa = TruncatedSVD(n_components=2)   # sklearn.decomposition n =2 for 2D
lsaOut = lsa.fit_transform(prideNounVecs)

# %% [markdown]
# Plot the results in a scatter plot. The results how words and how similar they are.

# %%
rcParams['figure.figsize'] = 16, 8
xs, ys = lsaOut[:,0], lsaOut[:,1]
for i in range(len(xs)): 
    plt.scatter(xs[i], ys[i])
    plt.annotate(prideNounLabels[i], (xs[i], ys[i]))

# %% [markdown]
# # Document Vectorization
#
# This uses a non-semantic technique for vectorizing documents, just using bag-of-words. We won't need any of the fancy features of SpaCy for this, just scikit-learn. We'll use a subset of the Inaugural Address Corpus that contains 20th and 21st century inaugural addresses of the US Presidents. These are in the folder 'inaugural'.
#
# First, we'll vectorize the corpus using scikit-learn's `TfidfVectorizer` class - covered in Text Mining and will also be revised in Day 2 briefly. This creates a matrix of word frequencies. (It doesn't actually use TF-IDF, since we're turning that off in the options below.)

# %%
# Let's build a corpus out of the 50 sentences in pride
# Do some cleaning first
from spacy.lang.en.stop_words import STOP_WORDS
stop_words = STOP_WORDS
prideSents = list(grail.sents)[0:1000]
prideSents = [sent for sent in prideSents if len(sent)!=1]
prideSents = [sent.text.translate(str.maketrans('', '', string.punctuation)) for sent in prideSents]

tfidf = TfidfVectorizer(prideSents, decode_error='ignore', stop_words = stop_words, use_idf=False)
#from sklearn.feature_extraction.text import get_feature_names
tfidf
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='ignore',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input=['SCENE 1', 'wind clop clop clop \n', 'KING ARTHUR',
#                        'Whoa there  ', 'clop clop clop \n', 'SOLDIER 1 Halt  ',
#                        'Who goes there\n', 'ARTHUR',
#                        'It is I Arthur son of Uther Pendragon from the castle '
#                        'of Camelot  ',
#                        'King of the Britons defeator of the Saxons sovereign '
#                        'of all England\...
#                 stop_words={"'d", "'ll", "'m", "'re", "'s", "'ve", 'a', 'about',
#                             'above', 'across', 'after', 'afterwards', 'again',
#                             'against', 'all', 'almost', 'alone', 'along',
#                             'already', 'also', 'although', 'always', 'am',
#                             'among', 'amongst', 'amount', 'an', 'and',
#                             'another', 'any', ...},
#                 strip_accents=None, sublinear_tf=False,
#                 token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None,
#                 use_idf=False, vocabulary=None)

# %%
inauguralFilenames = sorted(glob('inaugural/*'))

# Make labels by removing the directory name and .txt extension: 
labels = [filename.split('\\')[1] for filename in inauguralFilenames]  # for windows use \\
labels = [filename.split('.')[0] for filename in labels]
print (labels)

# While we're at it, let's make a list of the lengths (no of words, so we can use them to plot dot sizes. 
lengths = [len(open(filename, errors='ignore').read())/100 for filename in inauguralFilenames]  
print(lengths)
# Out:
# ['1901-McKinley', '1905-Roosevelt', '1909-Taft', '1913-Wilson', '1917-Wilson', '1921-Harding', '1925-Coolidge', '1929-Hoover', '1933-Roosevelt', '1937-Roosevelt', '1941-Roosevelt', '1945-Roosevelt', '1949-Truman', '1953-Eisenhower', '1957-Eisenhower', '1961-Kennedy', '1965-Johnson', '1969-Nixon', '1973-Nixon', '1977-Carter', '1981-Reagan', '1985-Reagan', '1989-Bush', '1993-Clinton', '1997-Clinton', '2001-Bush', '2005-Bush', '2009-Obama', '2017-Trump']
# [134.08, 55.68, 321.64, 95.63, 83.95, 202.98, 239.49, 217.64, 109.03, 106.07, 75.71, 30.39, 136.79, 139.55, 91.9, 76.18, 81.93, 116.24, 99.91, 68.73, 137.35, 145.61, 125.23, 91.14, 122.5, 90.53, 120.18, 134.39, 83.47]

# %%
tfidfOut = tfidf.fit_transform(inauguralFilenames)
# convert each of the docs in inauguralFilenames to tf-idf matrix
# Out:
# C:\Users\isstyc\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
tfidfOut.shape  # no of documents and no of features fitted to the original training corpus
# Out:
# (29, 49)

# %%
lsaOut = lsa.fit_transform(tfidfOut.todense())   # todense - how you store the matrices in memory
# lsa converts each of the term-document matrix into 2D by SVD (will be learnt in day 2)

# %%
rcParams['figure.figsize'] = 16, 8
# Add a manually compiled list of presidential party affiliations, 
# So that we can use this to color our dots. 
parties = 'rrrbbrrrbbbbbrrbbrrbrrrbbrrrr'
print (len(parties))
xs, ys = lsaOut[:,0], lsaOut[:,1]
for i in range(len(xs)): 
    try:
        plt.scatter(xs[i], ys[i], c=parties[i], s=lengths[i], alpha=0.5)
    except IndexError:
        continue
        
    plt.annotate(labels[i], (xs[i], ys[i]))
    print(labels[i], xs[i], ys[i])  #
# Out:
# 29
# 1901-McKinley 0.7109347056559997 -0.07558922004586842
# 1905-Roosevelt 0.7623805625470766 0.46500577967607354
# 1909-Taft 0.7109347046686035 -0.07483691866497968
# 1913-Wilson 0.7231340746242488 -0.10722438733981982
# 1917-Wilson 0.7231340747623357 -0.10715003241027467
# 1921-Harding 0.7109347002595746 -0.07646843331287867
# 1925-Coolidge 0.7109346992885236 -0.07862429941448415
# 1929-Hoover 0.7109347059876527 -0.07506981950285527
# 1933-Roosevelt 0.7623805624822478 0.4649935776184532
# 1937-Roosevelt 0.7623805624849824 0.46500029335428006
# 1941-Roosevelt 0.7623805625095152 0.46499449606511667
# 1945-Roosevelt 0.7623805625703245 0.4649850039422481
# 1949-Truman 0.7109347020454592 -0.07649653830492326
# 1953-Eisenhower 0.7231340738594326 -0.10779807670947689
# 1957-Eisenhower 0.7231340739019358 -0.10780500652667736
# 1961-Kennedy 0.710934702749258 -0.07771790619485273
# 1965-Johnson 0.7109347027321135 -0.07526146884613978
# 1969-Nixon 0.7231340747576761 -0.10692928244339335
# 1973-Nixon 0.7231340747581781 -0.10692065496182086
# 1977-Carter 0.7109347037712564 -0.07529853310518116
# 1981-Reagan 0.7231340746135545 -0.10708963028965099
# 1985-Reagan 0.7231340745907927 -0.10710423208442503
# 1989-Bush 0.7357594283875917 -0.18211492395797207
# 1993-Clinton 0.7231340739603324 -0.10739219571167818
# 1997-Clinton 0.7231340740572574 -0.10737314728136148
# 2001-Bush 0.735759428290392 -0.18219448199686814
# 2005-Bush 0.7357594283353017 -0.18215389830921658
# 2009-Obama 0.7109347038821752 -0.07554748565547693
# 2017-Trump 0.7109347042930318 -0.07557239516079017

# %% [markdown]
# # Document Similarity Matrix
#
# Using the `.similarity()` method from earlier that uses word vectors, we can very easily compute the document similarity between all the inaugural speeches amongst the Presidents.

# %%
docs = [nlp(open(filename, errors='ignore').read()) for filename in inauguralFilenames]  

import warnings
warnings.filterwarnings('ignore')
similarities = [ [doc.similarity(other) for other in docs] for doc in docs ]
similaritiesDf = pd.DataFrame(similarities, columns=labels, index=labels)

# %%
docs[0]
# Out:
# My fellow-citizens, when we assembled here on the 4th of March, 1897, there was great anxiety with regard to our currency and credit. None exists now. Then our Treasury receipts were inadequate to meet the current obligations of the Government. Now they are sufficient for all public needs, and we have a surplus instead of a deficit. Then I felt constrained to convene the Congress in extraordinary session to devise revenues to pay the ordinary expenses of the Government. Now I have the satisfaction to announce that the Congress just closed has reduced taxation in the sum of $41,000,000. Then there was deep solicitude because of the long depression in our manufacturing, mining, agricultural, and mercantile industries and the consequent distress of our laboring population. Now every avenue of production is crowded with activity, labor is well employed, and American products find good markets at home and abroad.
#
# Our diversified productions, however, are increasing in such unprecedented volume as to admonish us of the necessity of still further enlarging our foreign markets by broader commercial relations. For this purpose reciprocal trade arrangements with other nations should in liberal spirit be carefully cultivated and promoted.
#
# The national verdict of 1896 has for the most part been executed. Whatever remains unfulfilled is a continuing obligation resting with undiminished force upon the Executive and the Congress. But fortunate as our condition is, its permanence can only be assured by sound business methods and strict economy in national administration and legislation. We should not permit our great prosperity to lead us to reckless ventures in business or profligacy in public expenditures. While the Congress determines the objects and the sum of appropriations, the officials of the executive departments are responsible for honest and faithful disbursement, and it should be their constant care to avoid waste and extravagance.
#
# Honesty, capacity, and industry are nowhere more indispensable than in public employment. These should be fundamental requisites to original appointment and the surest guaranties against removal.
#
# Four years ago we stood on the brink of war without the people knowing it and without any preparation or effort at preparation for the impending peril. I did all that in honor could be done to avert the war, but without avail. It became inevitable; and the Congress at its first regular session, without party division, provided money in anticipation of the crisis and in preparation to meet it. It came. The result was signally favorable to American arms and in the highest degree honorable to the Government. It imposed upon us obligations from which we cannot escape and from which it would be dishonorable to seek escape. We are now at peace with the world, and it is my fervent prayer that if differences arise between us and other powers they may be settled by peaceful arbitration and that hereafter we may be spared the horrors of war.
#
# Intrusted by the people for a second time with the office of President, I enter upon its administration appreciating the great responsibilities which attach to this renewed honor and commission, promising unreserved devotion on my part to their faithful discharge and reverently invoking for my guidance the direction and favor of Almighty God. I should shrink from the duties this day assumed if I did not feel that in their performance I should have the co-operation of the wise and patriotic men of all parties. It encourages me for the great task which I now undertake to believe that those who voluntarily committed to me the trust imposed upon the Chief Executive of the Republic will give to me generous support in my duties to "preserve, protect, and defend, the Constitution of the United States" and to "care that the laws be faithfully executed." The national purpose is indicated through a national election. It is the constitutional method of ascertaining the public will. When once it is registered it is a law to us all, and faithful observance should follow its decrees.
#
# Strong hearts and helpful hands are needed, and, fortunately, we have them in every part of our beloved country. We are reunited. Sectionalism has disappeared. Division on public questions can no longer be traced by the war maps of 1861. These old differences less and less disturb the judgment. Existing problems demand the thought and quicken the conscience of the country, and the responsibility for their presence, as well as for their righteous settlement no more upon me than upon you. There are some national questions in the solution of which patriotism should exclude partisanship. Magnifying their difficulties will not take them off our hands nor facilitate their adjustment. Distrust of the capacity, integrity, and high purposes of the American people will not be an inspiring theme for future political contests. Dark pictures and gloomy forebodings are worse than useless. These only becloud, they do not help to point the way of safety and honor. "Hope maketh not ashamed." The prophets of evil were not the builders of the Republic, nor in its crises since have they saved or served it. The faith of the fathers was a mighty force in its creation, and the faith of their descendants has wrought its progress and furnished its defenders. They are obstructionists who despair, and who would destroy confidence in the ability of our people to solve wisely and for civilization the mighty problems resting upon them. The American people, intrenched in freedom at home, take their love for it with them wherever they go, and they reject as mistaken and unworthy the doctrine that we lose our own liberties by securing the enduring foundations of liberty to others. Our institutions will not deteriorate by extension, and our sense of justice will not abate under tropic suns in distant seas. As heretofore, so hereafter will the nation demonstrate its fitness to administer any new estate which events devolve upon it, and in the fear of God will "take occasion by the hand and make the bounds of freedom wider yet." If there are those among us who would make our way more difficult, we must not be disheartened, but the more earnestly dedicate ourselves to the task upon which we have rightly entered. The path of progress is seldom smooth. New things are often found hard to do. Our fathers found them so. We find them so. They are inconvenient. They cost us something. But are we not made better for the effort and sacrifice, and are not those we serve lifted up and blessed?
#
# We will be consoled, to, with the fact that opposition has confronted every onward movement of the Republic from its opening hour until now, but without success. The Republic has marched on and on, and its step has exalted freedom and humanity. We are undergoing the same ordeal as did our predecessors nearly a century ago. We are following the course they blazed. They triumphed. Will their successors falter and plead organic impotency in the nation? Surely after 125 years of achievement for mankind we will not now surrender our equality with other powers on matters fundamental and essential to nationality. With no such purpose was the nation created. In no such spirit has it developed its full and independent sovereignty. We adhere to the principle of equality among ourselves, and by no act of ours will we assign to ourselves a subordinate rank in the family of nations.
#
# My fellow-citizens, the public events of the past four years have gone into history. They are too near to justify recital. Some of them were unforeseen; many of them momentous and far-reaching in their consequences to ourselves and our relations with the rest of the world. The part which the United States bore so honorably in the thrilling scenes in China, while new to American life, has been in harmony with its true spirit and best traditions, and in dealing with the results its policy will be that of moderation and fairness.
#
# We face at this moment a most important question that of the future relations of the United States and Cuba. With our near neighbors we must remain close friends. The declaration of the purposes of this Government in the resolution of April 20, 1898, must be made good. Ever since the evacuation of the island by the army of Spain, the Executive, with all practicable speed, has been assisting its people in the successive steps necessary to the establishment of a free and independent government prepared to assume and perform the obligations of international law which now rest upon the United States under the treaty of Paris. The convention elected by the people to frame a constitution is approaching the completion of its labors. The transfer of American control to the new government is of such great importance, involving an obligation resulting from our intervention and the treaty of peace, that I am glad to be advised by the recent act of Congress of the policy which the legislative branch of the Government deems essential to the best interests of Cuba and the United States. The principles which led to our intervention require that the fundamental law upon which the new government rests should be adapted to secure a government capable of performing the duties and discharging the functions of a separate nation, of observing its international obligations of protecting life and property, insuring order, safety, and liberty, and conforming to the established and historical policy of the United States in its relation to Cuba.
#
# The peace which we are pledged to leave to the Cuban people must carry with it the guaranties of permanence. We became sponsors for the pacification of the island, and we remain accountable to the Cubans, no less than to our own country and people, for the reconstruction of Cuba as a free commonwealth on abiding foundations of right, justice, liberty, and assured order. Our enfranchisement of the people will not be completed until free Cuba shall "be a reality, not a name; a perfect entity, not a hasty experiment bearing within itself the elements of failure."
#
# While the treaty of peace with Spain was ratified on the 6th of February, 1899, and ratifications were exchanged nearly two years ago, the Congress has indicated no form of government for the Philippine Islands. It has, however, provided an army to enable the Executive to suppress insurrection, restore peace, give security to the inhabitants, and establish the authority of the United States throughout the archipelago. It has authorized the organization of native troops as auxiliary to the regular force. It has been advised from time to time of the acts of the military and naval officers in the islands, of my action in appointing civil commissions, of the instructions with which they were charged, of their duties and powers, of their recommendations, and of their several acts under executive commission, together with the very complete general information they have submitted. These reports fully set forth the conditions, past and present, in the islands, and the instructions clearly show the principles which will guide the Executive until the Congress shall, as it is required to do by the treaty, determine "the civil rights and political status of the native inhabitants." The Congress having added the sanction of its authority to the powers already possessed and exercised by the Executive under the Constitution, thereby leaving with the Executive the responsibility for the government of the Philippines, I shall continue the efforts already begun until order shall be restored throughout the islands, and as fast as conditions permit will establish local governments, in the formation of which the full co-operation of the people has been already invited, and when established will encourage the people to administer them. The settled purpose, long ago proclaimed, to afford the inhabitants of the islands self-government as fast as they were ready for it will be pursued with earnestness and fidelity. Already something has been accomplished in this direction. The Government's representatives, civil and military, are doing faithful and noble work in their mission of emancipation and merit the approval and support of their countrymen. The most liberal terms of amnesty have already been communicated to the insurgents, and the way is still open for those who have raised their arms against the Government for honorable submission to its authority. Our countrymen should not be deceived. We are not waging war against the inhabitants of the Philippine Islands. A portion of them are making war against the United States. By far the greater part of the inhabitants recognize American sovereignty and welcome it as a guaranty of order and of security for life, property, liberty, freedom of conscience, and the pursuit of happiness. To them full protection will be given. They shall not be abandoned. We will not leave the destiny of the loyal millions the islands to the disloyal thousands who are in rebellion against the United States. Order under civil institutions will come as soon as those who now break the peace shall keep it. Force will not be needed or used when those who make war against us shall make it no more. May it end without further bloodshed, and there be ushered in the reign of peace to be made permanent by a government of liberty under law!

# %%
# Requires the Seaborn library. 
rcParams['figure.figsize'] = 16, 8
seaborn.heatmap(similaritiesDf)

# %% [markdown]
# # Exercises (optional)
#
# 1. Extract all the events from _Pride and Prejudice_. (hint: look for the associated entity with events)
# 2. Find the shortest sentence in any inaugural address from our corpus.
# 3. Find the president that used the lowest proportions of adjectives (or nouns, verbs) in his inaugural address.
# 4. Find which of Charles Dickens's novels (or those of any other author) are the most semantically similar.
# The list of books may be found in https://www.gutenberg.org/
#
# # See Also
#
#  - [Textacy, higher-level NLP based on SpaCy](https://github.com/chartbeat-labs/textacy)
