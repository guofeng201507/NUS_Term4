# %% [markdown]
# ## Text Data Collection
#
# To do analysis in text, you need textual data! The sources of these data are varied. Some of them are for academic purposes - well labelled etc. But the truth is often you need to collect from the 'real-world'. These include collection from the Internet - RSS sites, google pages, social media etc.
#
# These form an important avenue to collect data from the Internet to do sentiment analysis. For eg. almost all news media provide RSS. Note that RSS is not UGC, and thence differences can be expected from social media or blogs. The content and how it is written are substantially different from 'short messages'. Most of the news content are also summarised by the headlines.
#
# In this notebook, we illustrate some examples of text data collection:
# - Rss feeds
# - Yelp (popular website by web scrapping)
# - Google search pages
# - Twitter (as usual!)

# %% [markdown]
# ## News from rss feeds
# We first illustrate news feeds with RSS Feeds.

# %%
# Importing packges
# Run this first before all code
from __future__ import unicode_literals
import os
import time
fpath = os.getcwd()
print (fpath)

import json
from feedparser import parse
from requests import get
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

TIMEOUT = 30
jsonlist = []
# Out:
# C:\Users\isstyc\Documents\NUS\Teaching\Practical Language Processing\New Media and Sentiment Mining\Workshops\Notebooks

# %%
import re, sys

def removeIndent(phrase):
    phrase=re.sub("\n",' ',phrase)
    phrase=re.sub("\r",' ',phrase)
    phrase=re.sub("\t",' ',phrase)
    return phrase

def removeWS(phrase):
    phrase=re.sub(' ','',phrase)
    return phrase

def removePunc(phrase):
    phrase=re.sub('&',' and ',phrase)
    phrase=re.sub(u"\"","\'", phrase)
    phrase=re.sub("\%","percent",phrase)
  #  phrase=re.sub(',','\,',phrase)
    return phrase

# %% [markdown]
# ### Examples of rss sites are listed below.
# - http://www.channelnewsasia.com/rss/latest_cna_biz_rss.xml # business
# - http://www.channelnewsasia.com/rss/latest_cna_sgbiz_rss.xml # sg biz
# - http://www.channelnewsasia.com/rss/latest_cna_world_rss.xml # world
# - http://www.channelnewsasia.com/rss/latest_cna_asiapac_rss.xml # asia pac
# <br>
#
# scmp
# - http://www.scmp.com/rss/2/feed  # HK
# - http://www.scmp.com/rss/10/feed  # business
# - http://www.scmp.com/rss/318421/feed # china feed

# %% [markdown]
# Code to retrieve RSS content is as below.

# %%
if __name__ == "__main__":
    newsurl = "http://www.channelnewsasia.com/rss/latest_cna_world_rss.xml"
    newsurl = "http://www.channelnewsasia.com/rss/latest_cna_biz_rss.xml"

    if os.path.exists("data\\cna.json"): os.remove("data\\cna.json") 
    ffile = open("data\\cna.json","w")
    rss = parse(newsurl)
    i = 1
    # print (rss)
    for rss_entry in rss['entries']:  # note format can change time to time
        if i > 30 : break
        i += 1
            #     try:
        url_link = rss_entry['id']
        url_content = get(url_link, timeout=TIMEOUT)
        if url_content.ok == True:                
            page = url_content.content.decode('utf-8','ignore')
            soup = BeautifulSoup(page, 'html.parser')
            data = soup.find("div", {"class": "c-rte--article"}).find_all('p')
            content = ""
            for element in data:
                #print (element.text)
                content += element.text.lstrip().rstrip()          
            #print (content)
            url_label = removePunc(rss_entry['title'])
            url_id = rss_entry['id']
            url_summary = rss_entry['summary']                  

            jdata = {"url_id": url_id, "content": {"url_label": url_label,"text":content }}
            jsonlist.append(jdata)            
    #    except Exception as e:
      #      pass
        #    print (u"Error site for " + url_link)
    jdata = json.dump(jsonlist, ffile)
    ffile.close()

# %%
ffile.close()

# %% [markdown]
# ## Data Collection from the Yelp sites
#
# Another source of data is user-generated data, of which we look at Yelp - a popular website for restuarants and other services reviews. It is possible to obtain via their website through their API. However there are limitations if done in this manner. Here, we use web scraping.

# %%
yelp_url = "https://www.yelp.com/biz/the-sushi-bar-singapore?osq=Restaurants"
ffile = open("data\\yelp_1.json","w")

url_content = get(yelp_url)
page = url_content.content.decode('utf-8','ignore')

soup = BeautifulSoup(page, 'html.parser')
data = soup.find_all("script", type="application/ld+json")[2].text.lstrip().rstrip()  
# there is structure change and second element is the right one
data = removeIndent(data)
#data = soup.find_all("content").text.lstrip().rstrip()

jsondata = json.loads(data)
json.dump(jsondata, ffile)

ffile.close()
#  <meta name="description" content="41 reviews of The Sushi Bar &#34;The service at Sushi Bar was great with an extremely polite and conscientious staff. Decor of the location was very intimate but also great for larger groups.  Came here on my birthday and ordered tuna sashimi (comes…"/>
# <meta property="og:title" content="Super Fun Event 1" />

# %% [markdown]
# ### Automation of web download
# Automating download of information from websites using Selenium. This package has recently been heavily used for RPA - robotic process automation. It is useful to know it well.

# %%
ffile = open("data\\yelp_2.json","w")
def getBS(data):
    soup = BeautifulSoup(data, "html.parser")
    data = soup.find_all("script", type="application/ld+json")[2].text.lstrip().rstrip()
    data = removeIndent(data)
    jsondata = json.loads(data)
    return jsondata

drive=webdriver.Chrome(fpath + "\\jar\\chromedriver.exe")
drive.set_page_load_timeout(10)
yelp_url = "https://www.yelp.com/biz/the-sushi-bar-singapore?start="
i=0

drive.get(yelp_url+str(i))
time.sleep(20)
data = drive.page_source
data0 = getBS(data)  # in dict format
print ("first clicked :" + str(i) + " downloaded")
reviews = {i : data0}

NbReviews = data0['aggregateRating']['reviewCount']
print ("Total no of reviews: " +str(NbReviews))

while i< NbReviews-20:  # code can be improved to look for next button in Selenium
    i=i+20
    drive.get(yelp_url+str(i))
    print ("no of reviews :" + str(i) + " downloaded")
    time.sleep(10)
    data = drive.page_source
    data = getBS(data) 
    #data = pd.DataFrame.to_json(getBS(data))  # in json format
    reviews[i]= data 

#jsondata = json.loads(data0)
json.dump(reviews, ffile)
ffile.close()
# Out:
# first clicked :0 downloaded
# Total no of reviews: 41
# no of reviews :20 downloaded
# no of reviews :40 downloaded

# %% [markdown]
# ## Data collection from Google Search
# It is also possible to extract search snippets from google search. From then, it is a simple task to use Selenium above to extract the contents returned from the search. An example below is done for search term 'Coffee'.
#
# To do run the code below, you need to obtain an API key and also create a custom search ID from the site
# https://developers.google.com/custom-search/v1/overview?csw=1

# %%
APIKEY = 'yourkey'

# https://developers.google.com/custom-search/v1/overview?csw=1

# %%
CSE_ID = 'Coffee'
CSE_ID = 'yourID'
# https://developers.google.com/custom-search/v1/overview?csw=1
# Also enable the "Search the entire web"

# %% [markdown]
# ![image.png](images/image.png)

# %%
# It looks something like this.........

# %% [markdown]
# ![image.png](images/image2.png)

# %%
#!pip install google-api-python-client

# %%
from googleapiclient.discovery import build
my_api_key = APIKEY
my_cse_id = CSE_ID

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res

# %%
result = google_search("covid", my_api_key, my_cse_id)
from pprint import pprint
pprint(result)
# Out:
# {'context': {'title': 'Coffee'},
#  'items': [{'cacheId': 'B_FPQc5umtEJ',
#             'displayLink': 'www.cdc.gov',
#             'formattedUrl': 'https://www.cdc.gov/coronavirus/2019-ncov/index.html',
#             'htmlFormattedUrl': 'https://www.cdc.gov/coronavirus/2019-ncov/index.html',
#             'htmlSnippet': 'Translations. Español &middot; 简体中文 &middot; Tiếng '
#                            'Việt &middot; 한국어 &middot; Other Languages. '
#                            '<b>COVID</b>-<br>\n'
#                            '19 UPDATES. Get email&nbsp;...',
#             'htmlTitle': 'Coronavirus Disease 2019 (<b>COVID</b>-19) | CDC',
#             'kind': 'customsearch#result',
#             'link': 'https://www.cdc.gov/coronavirus/2019-ncov/index.html',
#             'pagemap': {'contactpoint': [{'url': 'U.S. Department of Health & '
#                                                  'Human Services'},
#                                          {'url': 'USA.gov'}],
#                         'cse_image': [{'src': 'https://www.cdc.gov/coronavirus/2019-ncov/images/2019-coronavirus.png'}],
#                         'cse_thumbnail': [{'height': '159',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT4TywzMmH-sxU3r5uE_VAFH1B5XM1JnalfJbAyRQbxISkekGYUh-PDNjxB',
#                                            'width': '318'}],
#                         'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                                       'article:author': 'CDC',
#                                       'article:published_time': '2020-02-11',
#                                       'cdc:content_id': '28595',
#                                       'cdc:content_source': 'NATL CENTER FOR '
#                                                             'IMMUNIZATION AND '
#                                                             'RESPIRATORY '
#                                                             'DISEASES; '
#                                                             'DIVISION OF VIRAL '
#                                                             'DISEASES',
#                                       'cdc:last_published': '2020-04-17T22:34:21Z',
#                                       'cdc:last_reviewed': 'April 14, 2020',
#                                       'cdc:last_updated': 'April 14, 2020',
#                                       'cdc:maintained_by': 'NATL CENTER FOR '
#                                                            'IMMUNIZATION AND '
#                                                            'RESPIRATORY '
#                                                            'DISEASES',
#                                       'cdc:template_version': '4.0',
#                                       'cdc:wcms_build': '4.9.2 - b.2525',
#                                       'dc.date': '2020-04-17T10:17:17Z',
#                                       'fb:app_id': '205691699516606',
#                                       'mobile-web-app-capable': 'yes',
#                                       'og:author': 'CDC',
#                                       'og:description': 'Coronavirus disease '
#                                                         '2019 (COVID-19) is a '
#                                                         'virus (more '
#                                                         'specifically, a '
#                                                         'coronavirus) '
#                                                         'identified as the '
#                                                         'cause of an outbreak '
#                                                         'of respiratory '
#                                                         'illness first '
#                                                         'detected in Wuhan, '
#                                                         'China.',
#                                       'og:image': 'https://www.cdc.gov/coronavirus/2019-ncov/images/2019-coronavirus.png',
#                                       'og:image:type': 'image/png',
#                                       'og:site_name': 'Centers for Disease '
#                                                       'Control and Prevention',
#                                       'og:title': 'Coronavirus Disease 2019 '
#                                                   '(COVID-19)',
#                                       'og:type': 'article',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:creator': '@CDCgov',
#                                       'twitter:description': 'Coronavirus '
#                                                              'disease 2019 '
#                                                              '(COVID-19) is a '
#                                                              'virus (more '
#                                                              'specifically, a '
#                                                              'coronavirus) '
#                                                              'identified as '
#                                                              'the cause of an '
#                                                              'outbreak of '
#                                                              'respiratory '
#                                                              'illness first '
#                                                              'detected in '
#                                                              'Wuhan, China.',
#                                       'twitter:image:src': 'https://www.cdc.gov/coronavirus/2019-ncov/images/2019-coronavirus.png',
#                                       'twitter:site': '@CDCgov',
#                                       'twitter:title': 'Coronavirus Disease '
#                                                        '2019 (COVID-19)',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1, '
#                                                   'shrink-to-fit=no'}],
#                         'organization': [{'telephone': 'Call 800-232-4636',
#                                           'url': 'Email CDC-INFO'}]},
#             'snippet': 'Translations. Español · 简体中文 · Tiếng Việt · 한국어 · '
#                        'Other Languages. COVID-\n'
#                        '19 UPDATES. Get email\xa0...',
#             'title': 'Coronavirus Disease 2019 (COVID-19) | CDC'},
#            {'displayLink': 'www.worldometers.info',
#             'formattedUrl': 'https://www.worldometers.info/coronavirus/?utm_campaign...',
#             'htmlFormattedUrl': 'https://www.worldometers.info/coronavirus/?utm_campaign...',
#             'htmlSnippet': 'The coronavirus <b>COVID</b>-19 is affecting 210 '
#                            'countries and territories around the <br>\n'
#                            'world and 2 international conveyances. The day is '
#                            'reset after midnight GMT+0.',
#             'htmlTitle': 'Coronavirus Update (Live): 2,406,900 Cases and '
#                          '165,056 Deaths ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.worldometers.info/coronavirus/?utm_campaign=homeAdvegas1?',
#             'pagemap': {'cse_image': [{'src': 'http://www.worldometers.info/img/worldometers-fb.jpg'}],
#                         'cse_thumbnail': [{'height': '200',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQ62TJtYB9ZGN4h8qLssYoZl7eP4B17yR2zMxpedD1nbWgJ5x5WnKNRa7io',
#                                            'width': '200'}],
#                         'metatags': [{'msapplication-tilecolor': '#ffffff',
#                                       'msapplication-tileimage': '/favicon/ms-icon-144x144.png',
#                                       'og:image': 'http://www.worldometers.info/img/worldometers-fb.jpg',
#                                       'theme-color': '#ffffff',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'The coronavirus COVID-19 is affecting 210 countries '
#                        'and territories around the \n'
#                        'world and 2 international conveyances. The day is '
#                        'reset after midnight GMT+0.',
#             'title': 'Coronavirus Update (Live): 2,406,900 Cases and 165,056 '
#                      'Deaths ...'},
#            {'cacheId': 'q-_KCUnNXK8J',
#             'displayLink': 'www.who.int',
#             'formattedUrl': 'https://www.who.int/emergencies/diseases/novel.../events-as-they-happen',
#             'htmlFormattedUrl': 'https://www.who.int/emergencies/diseases/novel.../events-as-they-happen',
#             'htmlSnippet': 'Rolling updates on coronavirus disease '
#                            '(<b>COVID</b>-19). Updated 18 April 2020. <br>\n'
#                            'Getty images. © Credits. AddThis Sharing Buttons. '
#                            'Share to Print Share to Email<br>\n'
#                            '&nbsp;...',
#             'htmlTitle': 'Coronavirus (<b>COVID</b>-19) events as they happen',
#             'kind': 'customsearch#result',
#             'link': 'https://www.who.int/emergencies/diseases/novel-coronavirus-2019/events-as-they-happen',
#             'pagemap': {'cse_image': [{'src': 'https://www.who.int/images/default-source/temporary/getty-crowd.tmb-1200v.jpg?Culture=en&sfvrsn=3454a8ec_3'}],
#                         'cse_thumbnail': [{'height': '180',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTixixmtQx7SMTxiYz9DF44Etk7Z0MzTgixl0r_WLdJBJ27mlKK_WLY4-E0',
#                                            'width': '279'}],
#                         'metatags': [{'og:image': 'https://www.who.int/images/default-source/temporary/getty-crowd.tmb-1200v.jpg?Culture=en&sfvrsn=3454a8ec_3',
#                                       'og:locale': 'en_US',
#                                       'og:title': 'Coronavirus Disease '
#                                                   '(COVID-19) - events as they '
#                                                   'happen',
#                                       'twitter:card': 'summary_large_image',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'Rolling updates on coronavirus disease (COVID-19). '
#                        'Updated 18 April 2020. \n'
#                        'Getty images. © Credits. AddThis Sharing Buttons. '
#                        'Share to Print Share to Email\n'
#                        '\xa0...',
#             'title': 'Coronavirus (COVID-19) events as they happen'},
#            {'displayLink': 'en.wikipedia.org',
#             'formattedUrl': 'https://en.wikipedia.org/wiki/Coronavirus_disease_2019',
#             'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Coronavirus_disease_2019',
#             'htmlSnippet': 'Coronavirus disease 2019 (<b>COVID</b>-19) is an '
#                            'infectious disease caused by severe <br>\n'
#                            'acute respiratory syndrome coronavirus 2 '
#                            '(SARS-CoV-2). The disease was&nbsp;...',
#             'htmlTitle': 'Coronavirus disease 2019 - Wikipedia',
#             'kind': 'customsearch#result',
#             'link': 'https://en.wikipedia.org/wiki/Coronavirus_disease_2019',
#             'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Symptoms_of_coronavirus_disease_2019_3.0.svg/1200px-Symptoms_of_coronavirus_disease_2019_3.0.svg.png'}],
#                         'cse_thumbnail': [{'height': '181',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSt0bbwvWDca3CtUjmE_8GscYALr_HcBrPLfL-cYi7BnZfmATOJuaMCMp4',
#                                            'width': '278'}],
#                         'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Symptoms_of_coronavirus_disease_2019_3.0.svg/1200px-Symptoms_of_coronavirus_disease_2019_3.0.svg.png',
#                                       'referrer': 'origin'}]},
#             'snippet': 'Coronavirus disease 2019 (COVID-19) is an infectious '
#                        'disease caused by severe \n'
#                        'acute respiratory syndrome coronavirus 2 (SARS-CoV-2). '
#                        'The disease was\xa0...',
#             'title': 'Coronavirus disease 2019 - Wikipedia'},
#            {'cacheId': '7bSfrAPgJGUJ',
#             'displayLink': 'covid19.nj.gov',
#             'formattedUrl': 'https://covid19.nj.gov/',
#             'htmlFormattedUrl': 'https://<b>covid</b>19.nj.gov/',
#             'htmlSnippet': 'The official <b>COVID</b>-19 Information Hub for '
#                            'the State of New Jersey. Find the latest <br>\n'
#                            'news, guidance, resources, and support here.',
#             'htmlTitle': 'New Jersey <b>COVID</b>-19 Information Hub',
#             'kind': 'customsearch#result',
#             'link': 'https://covid19.nj.gov/',
#             'pagemap': {'cse_image': [{'src': 'https://njhealth.maps.arcgis.com/sharing/rest/content/items/32f43c4587cc4b899fd8106c9e1c49db/data'}],
#                         'cse_thumbnail': [{'height': '100',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQmZ1uMnjdKRqcDoJdj-_EHV0asefoFGa3qASs3pGBGPJodrmThkPHi',
#                                            'width': '100'}],
#                         'metatags': [{'format-detection': 'telephone=no',
#                                       'og:description': 'The official COVID-19 '
#                                                         'Information Hub for '
#                                                         'the State of New '
#                                                         'Jersey. Find the '
#                                                         'latest news, '
#                                                         'guidance, resources, '
#                                                         'and support here.',
#                                       'og:image': 'https://covid19.nj.gov/',
#                                       'og:title': 'New Jersey COVID-19 '
#                                                   'Information Hub',
#                                       'og:type': 'website',
#                                       'og:url': 'https://covid19.nj.gov/',
#                                       'twitter:card': 'summary',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1, '
#                                                   'maximum-scale=5'}]},
#             'snippet': 'The official COVID-19 Information Hub for the State of '
#                        'New Jersey. Find the latest \n'
#                        'news, guidance, resources, and support here.',
#             'title': 'New Jersey COVID-19 Information Hub'},
#            {'cacheId': 'XFkBpBqt2iUJ',
#             'displayLink': 'coronavirus.ohio.gov',
#             'formattedUrl': 'https://coronavirus.ohio.gov/wps/portal/gov/covid-19/home',
#             'htmlFormattedUrl': 'https://coronavirus.ohio.gov/wps/portal/gov/<b>covid</b>-19/home',
#             'htmlSnippet': 'The <b>COVID</b>-19 pandemic can be overwhelming '
#                            'for parents and concerning to <br>\n'
#                            'children. Ohio Department of Health Director Amy '
#                            'Acton, MD, MPH, recommends<br>\n'
#                            '&nbsp;...',
#             'htmlTitle': '<b>COVID</b>-19',
#             'kind': 'customsearch#result',
#             'link': 'https://coronavirus.ohio.gov/wps/portal/gov/covid-19/home',
#             'pagemap': {'cse_image': [{'src': 'https://coronavirus.ohio.gov/wps/wcm/connect/gov/93f29fe8-3b8e-4721-bf24-b3f57cfbba16/privatelabtest.jpg?MOD=AJPERES&CACHEID=ROOTWORKSPACE.Z18_M1HGGIK0N0JO00QO9DDDDM3000-93f29fe8-3b8e-4721-bf24-b3f57cfbba16-n6qmK0S'}],
#                         'cse_thumbnail': [{'height': '93',
#                                            'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ5-mP0-mRqUAUxYkcbfikR_Rm2LZDuTZwkOR4TuR5sFIac9jXnkhDZ',
#                                            'width': '124'}],
#                         'metatags': [{'viewport': 'initial-scale=1, '
#                                                   'minimum-scale=1, '
#                                                   'width=device-width, '
#                                                   'target-densitydpi=device-dpi'}]},
#             'snippet': 'The COVID-19 pandemic can be overwhelming for parents '
#                        'and concerning to \n'
#                        'children. Ohio Department of Health Director Amy '
#                        'Acton, MD, MPH, recommends\n'
#                        '\xa0...',
#             'title': 'COVID-19'},
#            {'cacheId': '0C2yRR8Hyl0J',
#             'displayLink': 'floridahealthcovid19.gov',
#             'formattedUrl': 'https://floridahealthcovid19.gov/',
#             'htmlFormattedUrl': 'https://floridahealth<b>covid</b>19.gov/',
#             'htmlSnippet': 'The Florida Department of Health is issuing 2019 '
#                            'Novel Coronavirus (<b>COVID</b>-19) <br>\n'
#                            'updates every day to keep residents and visitors '
#                            'safe and aware.',
#             'htmlTitle': 'Home | Florida Department of Health <b>COVID</b>-19 '
#                          'Outbreak',
#             'kind': 'customsearch#result',
#             'link': 'https://floridahealthcovid19.gov/',
#             'pagemap': {'cse_image': [{'src': 'https://s33330.pcdn.co/wp-content/uploads/2020/03/og-img_v1a.jpg'}],
#                         'cse_thumbnail': [{'height': '163',
#                                            'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-8zuYeIl0kFo8pwT5wRtDkRHMoxdBy24czhyHTAFqQhZRcmOdE3H_lYo',
#                                            'width': '310'}],
#                         'metatags': [{'og:description': '...',
#                                       'og:image': 'https://s33330.pcdn.co/wp-content/uploads/2020/03/og-img_v1a.jpg',
#                                       'og:image:height': '630',
#                                       'og:image:secure_url': 'https://s33330.pcdn.co/wp-content/uploads/2020/03/og-img_v1a.jpg',
#                                       'og:image:width': '1200',
#                                       'og:locale': 'en_US',
#                                       'og:site_name': 'Florida Department of '
#                                                       'Health COVID-19 '
#                                                       'Outbreak',
#                                       'og:title': 'Home',
#                                       'og:type': 'article',
#                                       'og:url': 'https://floridahealthcovid19.gov/',
#                                       'twitter:card': 'summary',
#                                       'twitter:description': 'Providing '
#                                                              'regular updates '
#                                                              'on the '
#                                                              'coronavirus '
#                                                              'outbreak in '
#                                                              'Florida',
#                                       'twitter:image': 'http://s33330.p1166.sites.pressdns.com/wp-content/uploads/2020/03/og-img_v1a.jpg',
#                                       'twitter:title': 'Florida Department of '
#                                                        'Health COVID-19 '
#                                                        'Response',
#                                       'twitter:url': 'https://floridahealthcovid19.gov/',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'The Florida Department of Health is issuing 2019 Novel '
#                        'Coronavirus (COVID-19) \n'
#                        'updates every day to keep residents and visitors safe '
#                        'and aware.',
#             'title': 'Home | Florida Department of Health COVID-19 Outbreak'},
#            {'cacheId': 'IAi0N_1HWqEJ',
#             'displayLink': 'coronavirus.jhu.edu',
#             'formattedUrl': 'https://coronavirus.jhu.edu/map.html',
#             'htmlFormattedUrl': 'https://coronavirus.jhu.edu/map.html',
#             'htmlSnippet': 'Coronavirus <b>COVID</b>-19 Global Cases by the '
#                            'Center for Systems Science and <br>\n'
#                            'Engineering (CSSE) at Johns Hopkins University '
#                            '(JHU)',
#             'htmlTitle': '<b>COVID</b>-19 Map - Johns Hopkins Coronavirus '
#                          'Resource Center',
#             'kind': 'customsearch#result',
#             'link': 'https://coronavirus.jhu.edu/map.html',
#             'pagemap': {'cse_image': [{'src': 'https://coronavirus.jhu.edu/images/assets/a6cf4dca15214cd39a2816380cc893ef.png'}],
#                         'cse_thumbnail': [{'height': '159',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT6IQPdXzMye0jqVp9VXg3JR9T9HH1P1vLv2zgod-SCoaXKV0a2tnEleQ5A',
#                                            'width': '317'}],
#                         'metatags': [{'og:description': 'Coronavirus COVID-19 '
#                                                         'Global Cases by the '
#                                                         'Center for Systems '
#                                                         'Science and '
#                                                         'Engineering (CSSE) at '
#                                                         'Johns Hopkins '
#                                                         'University (JHU)',
#                                       'og:image': 'https://coronavirus.jhu.edu/images/assets/a6cf4dca15214cd39a2816380cc893ef.png',
#                                       'og:image:secure_url': 'https://coronavirus.jhu.edu/images/assets/a6cf4dca15214cd39a2816380cc893ef.png',
#                                       'og:site_name': 'Johns Hopkins '
#                                                       'Coronavirus Resource '
#                                                       'Center',
#                                       'og:title': 'COVID-19 Map',
#                                       'og:type': 'website',
#                                       'og:url': 'https://coronavirus.jhu.edu/map.html',
#                                       'theme-color': '#000000',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:creator': '@JohnsHopkins',
#                                       'twitter:site': '@JohnsHopkins',
#                                       'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no'}]},
#             'snippet': 'Coronavirus COVID-19 Global Cases by the Center for '
#                        'Systems Science and \n'
#                        'Engineering (CSSE) at Johns Hopkins University (JHU)',
#             'title': 'COVID-19 Map - Johns Hopkins Coronavirus Resource '
#                      'Center'},
#            {'cacheId': 'gp5fnBLhW-gJ',
#             'displayLink': 'www.osha.gov',
#             'formattedUrl': 'https://www.osha.gov/covid-19',
#             'htmlFormattedUrl': 'https://www.osha.gov/<b>covid</b>-19',
#             'htmlSnippet': '<b>COVID</b>-19. Coronavirus Illustration | Photo: '
#                            'CDC. Overview. This image depicts a <br>\n'
#                            'healthcare provider donning a pair of beige '
#                            'latex&nbsp;...',
#             'htmlTitle': 'Safety and Health Topics | <b>COVID</b>-19 | '
#                          'Occupational Safety and ...',
#             'kind': 'customsearch#result',
#             'link': 'https://www.osha.gov/covid-19',
#             'pagemap': {'metatags': [{'agency': 'OSHA',
#                                       'audience': 'GENERAL',
#                                       'contentowner': 'OSHA-Directorate of '
#                                                       'Technical Support and '
#                                                       'Emergency Management',
#                                       'date': '04/16/2020',
#                                       'doctype': 'HTML',
#                                       'expdate': 'none',
#                                       'subagency': 'NONE',
#                                       'subject': 'Workplace Safety & Health',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1.0'}]},
#             'snippet': 'COVID-19. Coronavirus Illustration | Photo: CDC. '
#                        'Overview. This image depicts a \n'
#                        'healthcare provider donning a pair of beige latex\xa0'
#                        '...',
#             'title': 'Safety and Health Topics | COVID-19 | Occupational '
#                      'Safety and ...'},
#            {'cacheId': 'OjPhZ_zgCzUJ',
#             'displayLink': 'www.ncdhhs.gov',
#             'formattedUrl': 'https://www.ncdhhs.gov/divisions/public-health/covid19',
#             'htmlFormattedUrl': 'https://www.ncdhhs.gov/divisions/public-health/<b>covid</b>19',
#             'htmlSnippet': '<b>COVID</b>-19 Videos. - In sharing a path for '
#                            'easing certain <b>COVID</b>-19 restrictions, <br>\n'
#                            'Governor Cooper says more progress is '
#                            'needed&nbsp;...',
#             'htmlTitle': 'Coronavirus Disease 2019 (COVID-19) Response - '
#                          'NCDHHS',
#             'kind': 'customsearch#result',
#             'link': 'https://www.ncdhhs.gov/divisions/public-health/covid19',
#             'pagemap': {'breadcrumb': [{'title': 'NCDHHS', 'url': 'NCDHHS'},
#                                        {'title': 'Divisions',
#                                         'url': 'Divisions'},
#                                        {'title': 'Public Health',
#                                         'url': 'Public Health'},
#                                        {'title': 'Coronavirus Disease 2019 '
#                                                  '(COVID-19) Response'}],
#                         'cse_image': [{'src': 'https://files.nc.gov/ncdhhs/styles/resp_hero-breakpoints_theme_nc_base_theme_phone_1x/public/COVID19-HaveSymptoms_StayHome_web%20slider1.jpg?itok=3XNBE4lI&timestamp=1585343523'}],
#                         'cse_thumbnail': [{'height': '128',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcT17X_q_du2BA1x4oPCSXZ20bJc9GbYViIp52hyI52hvyQ1gHz1dexL4SL9',
#                                            'width': '320'}],
#                         'metatags': [{'msapplication-tilecolor': '#ffffff',
#                                       'msapplication-tileimage': '/ms-icon-144x144.png',
#                                       'theme-color': '#ffffff',
#                                       'viewport': 'width=device-width, '
#                                                   'minimum-scale=1, '
#                                                   'maximum-scale=1, '
#                                                   'user-scalable=no'}],
#                         'thing': [{'description': 'Dial 2-1-1 or 888-892-1162. '
#                                                   'Get updates by texting '
#                                                   'COVIDNC to 898211. Click '
#                                                   'here to read Frequently '
#                                                   'Asked Questions.',
#                                    'name': 'NC COVID-19 Information',
#                                    'url': 'NC COVID-19 Information Dial 2-1-1 '
#                                           'or 888-892-1162. Get updates by '
#                                           'texting COVIDNC to 898211. Click '
#                                           'here to read Frequently Asked '
#                                           'Questions.'},
#                                   {'description': 'Get updates from reliable '
#                                                   'sources.',
#                                    'name': 'Latest Updates',
#                                    'url': 'Latest Updates Get updates from '
#                                           'reliable sources.'},
#                                   {'description': 'Basic information about the '
#                                                   'virus.',
#                                    'name': 'COVID-19',
#                                    'url': 'COVID-19 Basic information about '
#                                           'the virus.'},
#                                   {'description': 'For households who need '
#                                                   'help buying food, health '
#                                                   'insurance or other support.',
#                                    'name': 'Assistance',
#                                    'url': 'Assistance For households who need '
#                                           'help buying food, health insurance '
#                                           'or other support.'},
#                                   {'description': 'What businesses and '
#                                                   'employers can do.',
#                                    'name': 'Businesses and Employers',
#                                    'url': 'Businesses and Employers What '
#                                           'businesses and employers can do.'},
#                                   {'description': 'Information for families '
#                                                   'and providers.',
#                                    'name': 'Child Care',
#                                    'url': 'Child Care Information for families '
#                                           'and providers.'},
#                                   {'description': 'Guidance for community '
#                                                   'groups and planning for '
#                                                   'events and mass gatherings.',
#                                    'name': 'Community Events',
#                                    'url': 'Community Events Guidance for '
#                                           'community groups and planning for '
#                                           'events and mass gatherings.'},
#                                   {'description': 'Information about '
#                                                   'volunteering and donations.',
#                                    'name': 'How to Help',
#                                    'url': 'How to Help Information about '
#                                           'volunteering and donations.'},
#                                   {'description': 'Steps to stay healthy.',
#                                    'name': 'Individuals and Families',
#                                    'url': 'Individuals and Families Steps to '
#                                           'stay healthy.'},
#                                   {'description': 'Information and guidance '
#                                                   'for local health '
#                                                   'departments.',
#                                    'name': 'Local Health Departments',
#                                    'url': 'Local Health Departments '
#                                           'Information and guidance for local '
#                                           'health departments.'},
#                                   {'description': 'What facilities can do.',
#                                    'name': 'Long-term Care Facilities',
#                                    'url': 'Long-term Care Facilities What '
#                                           'facilities can do.'},
#                                   {'description': 'Resources to manage overall '
#                                                   'health and reduce '
#                                                   'stress/anxiety.',
#                                    'name': 'Managing Overall Health',
#                                    'url': 'Managing Overall Health Resources '
#                                           'to manage overall health and reduce '
#                                           'stress/anxiety.'},
#                                   {'description': 'For doctors, hospitals, '
#                                                   'local health departments '
#                                                   'and behavioral health '
#                                                   'providers.',
#                                    'name': 'Providers',
#                                    'url': 'Providers For doctors, hospitals, '
#                                           'local health departments and '
#                                           'behavioral health providers.'},
#                                   {'description': 'What to look for and when '
#                                                   'to get tested.',
#                                    'name': 'Symptoms and Testing',
#                                    'url': 'Symptoms and Testing What to look '
#                                           'for and when to get tested.'}],
#                         'videoobject': [{'name': 'NC Emergency Management '
#                                                  'Director Mike Sprayberry on '
#                                                  'using 9-1-1 for true '
#                                                  'emergencies only',
#                                          'url': 'NC Emergency Management '
#                                                 'Director Mike Sprayberry on '
#                                                 'using 9-1-1 for true '
#                                                 'emergencies only'}]},
#             'snippet': 'COVID-19 Videos. - In sharing a path for easing '
#                        'certain COVID-19 restrictions, \n'
#                        'Governor Cooper says more progress is needed\xa0...',
#             'title': 'Coronavirus Disease 2019 (COVID-19) Response - NCDHHS'}],
#  'kind': 'customsearch#search',
#  'queries': {'nextPage': [{'count': 10,
#                            'cx': '010439152562262418626:eaztx9vovmv',
#                            'inputEncoding': 'utf8',
#                            'outputEncoding': 'utf8',
#                            'safe': 'off',
#                            'searchTerms': 'covid',
#                            'startIndex': 11,
#                            'title': 'Google Custom Search - covid',
#                            'totalResults': '1750000000'}],
#              'request': [{'count': 10,
#                           'cx': '010439152562262418626:eaztx9vovmv',
#                           'inputEncoding': 'utf8',
#                           'outputEncoding': 'utf8',
#                           'safe': 'off',
#                           'searchTerms': 'covid',
#                           'startIndex': 1,
#                           'title': 'Google Custom Search - covid',
#                           'totalResults': '1750000000'}]},
#  'searchInformation': {'formattedSearchTime': '0.80',
#                        'formattedTotalResults': '1,750,000,000',
#                        'searchTime': 0.802077,
#                        'totalResults': '1750000000'},
#  'url': {'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json',
#          'type': 'application/json'}}

# %%
import json
rt =  json.dumps(result)
json.dump(rt, open("data\\liverpool.json","w"))

# %% [markdown]
# ### Twitter data download

# %% [markdown]
# For download of twitter feeds using Python, consider using the library tweepy. https://tweepy.readthedocs.io/en/latest/getting_started.html
#
# First create an application on Twitter. Follow the steps in https://developer.twitter.com/en/apps/ to obtain the keys belowmentioned.

# %%
consumer_key = "xxx" 
consumer_secret = "xx"
access_token = "xx-xxx"
access_token_secret = "xxx"

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Equity investors seem to be focusing on positive COVID-19 developments, but the fundamental backdrop remains weak.… https://t.co/oYQ1PCtJ3W
# As momentum builds behind debt relief for Africa’s heavily indebted economies, a tussle is brewing between the West… https://t.co/owNBprDedv
# The change will affect the movement of individuals and commercial vehicles such as cargo lorries.
#
# https://t.co/NfWYB50ISM
# Messages in response to the pandemic are getting repetitive, and risk appearing insincere, some in the industry say https://t.co/xHudiuchiD
# In Dubai, citizens and expats can summon groceries and services – even a single chocolate bar – within minutes.
#
# https://t.co/Pvkhqm9T7Z
# BREAKING: Singapore preliminarily confirms 1,111 COVID-19 new cases, crosses 9,000 mark
# https://t.co/gg5yWCURRo https://t.co/UhB4h6F7lq
# Genting Bhd. and its units are planning the first group-wide salary cut since its founding in 1965.
# #YahooFinance
# https://t.co/PXmFdLjyvq
# A series of purges has strengthened President Xi’s authority over China’s law-enforcement apparatus—key to his camp… https://t.co/fdqrgdNFZO
# "It's gonna be a tragic little Sahara when we come back." Some office plants get rescued; others face a sad fate. https://t.co/g5cQxmBru3
# Our Fixed Income CIO Sonal Desai discusses possible recovery outcomes if parts of the US start to reopen. Learn mor… https://t.co/AThJtxMwND
# Across Latin America, the number of calls to helplines have soared, made by victims of domestic violence who cannot… https://t.co/pLAFS5wAUU
# Shaanxi province reported 21 new infections from abroad as well as seven cases with no clinical symptoms, all of wh… https://t.co/ZHFcbCX7U4
# New York state has asked the federal government for a $4 billion no-interest loan to cover unemployment payments fo… https://t.co/Ufqk96kcnx
# #EnergyEfficiency has a strong role to play in boosting jobs &amp; economic growth while also supporting clean energy t… https://t.co/WujWAmc4J8
# The airline has more than A$5 billion of debt.
# #YahooFinance
#
# https://t.co/NPqpgeJArD
# Kevin Love speaks about his breakfast routine, the importance of FaceTime and how he’s working out right now https://t.co/2SmhUIZxHe
# "If I can’t make art, I don’t know what I can do."
#
# https://t.co/Ky9SQ2r3P7
# People must be ready for a new way of living to allow society to function while the coronavirus is being kept in ch… https://t.co/X1he5i8nei
# Chi Zhang &amp; Kaiyang Pan from @finfabrik are speaking about building a Verifiable Health Code with Hyperledger Indy… https://t.co/fGd0hsmYZi
# Shake Shack said it would return a $10 million loan from a federal aid program that some small restaurants say shou… https://t.co/32d97UOlWX

# %% [markdown]
# This obtains tweets by the hashtag, in this case 'man utd'.

# %%
manutd = tweepy.Cursor(api.search, q='man utd').items(10)
for tweet in manutd:
   print (tweet.created_at, tweet.text, tweet.lang)
# Out:
# 2020-04-21 07:44:59 This list is really interesting. Wolves has the 5th richest owner in the league but doesn't have a single world cla… https://t.co/7kQslzDiRj en
# 2020-04-21 07:44:46 RT @TheSaItIsHere: This quarantine's made me realise why everyone hates Man Utd fans en
# 2020-04-21 07:44:26 Man Utd identify Sancho transfer alternative as Solskjaer eyes new forward https://t.co/XzGvCUuq7L https://t.co/BW9nuYw0fw en
# 2020-04-21 07:43:59 Man Utd identify Sancho transfer alternative as Solskjaer eyes new forward https://t.co/1hfTxVdRBv en
# 2020-04-21 07:43:57 FA Cup Final 25th May 1963 Man Utd 3 - Leicester City 1 Wonderful (albeit silent) footage of the dressing room afte… https://t.co/mg4jKo7ooi en
# 2020-04-21 07:43:36 How Man Utd could line up with Joao Felix and two other signings next season #MUFC
# https://t.co/vxgJ9QHsik https://t.co/WgyPdc58Ho en
# 2020-04-21 07:43:35 @ManUtdInPidgin @ManUtd @andrinhopereira Chop bench abi make them dash am out, bcus he's not even worth to be on Man utd bench.. Otu oshi.. en
# 2020-04-21 07:43:33 Atletico Madrid insist Man Utd target Saul Niguez will not be sold for less than £130m release clause https://t.co/WoY5Z40bzW #FOOTBALL en
# 2020-04-21 07:43:10 RT @goal: Who are Man Utd's three best players ever? 🤔 en
# 2020-04-21 07:42:36 I’m back. Just skip to 1:20. There isn’t a player at the club who can do that. Every top club has atleast one playe… https://t.co/frPRoyfCUe en
